# %% [markdown]
# Split the data into sections based on the class : NOTHING, PASS_L, MAUL ETC (easy based on the frame counts in the RLE classification) and save each section as a separate video file: PASS_L_01,avi, PASS_L_02.mp3 etc etc.
#
# THIS Needs a code review as any off-by-one error in calculating clips start/ends will accumulate of clips, and at 1000's of clips it could be massively off by the end!
#
# The clip extarction method is block-sequential i.e. Clip 1 might be frames 1-35, clip 2 frames 36-70 etc etc.
#
# We could make it a running block:
# Clip 1: 1-35
# Clip 2: 2-36 etc etc
#
# Any clips short than the given lentgh are dumped - for long desired clip lentghs this can easily dump whole clips - particulalrly clips from classes that are inherant short (e.g. PASS).
#
# Any residual frames from clips lomger than the desired clip length are similarly dumped.

# %%
import cv2
import numpy as np
# from google.colab.patches import cv2_imshow
import re
import os
import random
import shutil

# %%
def getVideoFrames(filepath,start,length):
  '''
    Function to return a set length extract of a video file starting from a given frame
    Parameters:
    filepath (str): path and file name of the video from which to extract a clip
    start (int): frame number to start the clip at
    length (int): length in frames of the desired clip

    Returns:
    list(np,array): a list of frames from the video as np.arrays
    tuple(int,int) : (width, height) of the captured clip
    fps (float): fps of the captured clip
  '''
  cap = cv2.VideoCapture(filepath)
  width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH ))
  height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT ))
  fps =  int(cap.get(cv2.CAP_PROP_FPS))
  #print(f"Width : {width} Height: {height} FPS: {fps}")
  cap.set(cv2.CAP_PROP_POS_FRAMES, start-1)
  frames_list=list()
  for frame_count in range(start,start+length):
    ret, frame = cap.read()
    frames_list.append(frame)
  cap.release()
  return frames_list, (width,height), fps

# %%
def getClipDetails(filepath):
  '''
    Function to Parse the label file into list of labels and run lengths
    Parameters:
    filepath (str): path and file name of the label file
    Returns:
    list(tuple(str,int)): a list of tuples of (label,frame length)
  '''
  with open(filepath ) as f:
      lines = f.readlines()

  label_tuples = list()
  for line in lines:
    #print(line)
    label_match = re.search(r'(?<=Label.)(.*)(?=:)',line)
    #print(label_match.group())
    frame_match = re.search(r'(?<=:)(.*)(?=\n)',line)
    if frame_match is None:
      frame_match = re.search(r'(?<=:)(.*)',line)
    #print(frame_match.group())
    label_tuples.append((label_match.group(),int(frame_match.group())))
  return label_tuples

# %%
# Define the location of the label file
labelpath = "/dcs/large/u1901447/labels/gallconcat.lbl"
# Define the location of the video we are processing
videopath = "/dcs/large/u1901447/videos/220611galleivnor_2_movie-001.mov"
# Define the folder we want to save the extracted fragments into
save_path_root = '/dcs/large/u1901447/videos/clips'
label_tuples = getClipDetails(labelpath)

# %%
# Create folders to store the extracted clips

all_labels = set(l[0] for l in label_tuples)
for label in all_labels:
  if not os.path.exists(f"{save_path_root}/all_35_frames/{label}"):
      # if the demo_folder directory is not presenth 
      # then create it.
      os.makedirs(f"{save_path_root}/all_35_frames/{label}")

# %% [markdown]
# Here we cut the long video into smaller clips based on the classification made in in the labels file. They are given filenames incrementally as the segentation progresses. Clips with less than 15 frames are dropped.
#
# Note that if this program is run on different files the filenames WILL be overwritten!

# %%
# Setup a dict to store the counts of files of each label so we can have a unique file name for each type of label
# label_indexer = dict()
# Get an iterable of unique labels
all_labels = set(l[0] for l in label_tuples)
for label in all_labels:
  if not os.path.exists(f"{save_path_root}/all_35_frames/{label}"):
      # if the demo_folder directory is not present 
      # then create it.
      os.makedirs(f"{save_path_root}/all_35_frames/{label}")
# To incrementaly number the saved clips with unique file names
file_counter = 1
# To point to which frame we are currently at for the extraction function
frame_counter = 1
clip_length = 35

# Loop through the RLE data calling the frame extractor function, then saving the extracted clips to a new MP4 file
for label,frames_count in label_tuples:
    print(f"Processing a run of {frames_count} frames with label {label}")
    frames_to_process = frames_count
    # if the clip length is greater than required, split it into multiple clips
    while frames_to_process > clip_length:
        #  Get 'clip_length' frames from the given video
        frames, videodims, fps = getVideoFrames(videopath,frame_counter,clip_length)
        #print(f"Video Dims : {videodims} FPS: {fps}")
        videocap_name = f"{save_path_root}/all_{clip_length}_frames/{label}/{label}_{file_counter}.mp4"
        # increment the counter fot the number of clips processed so far (so each gets a un ique name)
        file_counter+=1
        out = cv2.VideoWriter(videocap_name, cv2.VideoWriter_fourcc(*'mp4v'), fps, videodims)
        for frame in frames:
            out.write(frame)
        out.release()
        print(f"Saved filename {videocap_name} with label {label} and {clip_length} frames from {frame_counter} to {frame_counter+clip_length}")
        # update the count of remaining frames to process in this clip
        frames_to_process -= clip_length
        print(f"There are {frames_to_process} frames left in this clip")
        # move the start position on by 'clip_length' positions
        frame_counter += clip_length

    print(f"Dropped label a run of {label} with {frames_to_process} frames from {frame_counter} to {frame_counter+frames_to_process}")
    # Step the frame counter on to be ready for the next read
    frame_counter += frames_to_process
# Out:
# Processing a run of 249 frames with label NOTHING
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/NOTHING/NOTHING_1.mp4 with label NOTHING and 35 frames from 1 to 36
# There are 214 frames left in this clip
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/NOTHING/NOTHING_2.mp4 with label NOTHING and 35 frames from 36 to 71
# There are 179 frames left in this clip
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/NOTHING/NOTHING_3.mp4 with label NOTHING and 35 frames from 71 to 106
# There are 144 frames left in this clip
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/NOTHING/NOTHING_4.mp4 with label NOTHING and 35 frames from 106 to 141
# There are 109 frames left in this clip
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/NOTHING/NOTHING_5.mp4 with label NOTHING and 35 frames from 141 to 176
# There are 74 frames left in this clip
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/NOTHING/NOTHING_6.mp4 with label NOTHING and 35 frames from 176 to 211
# There are 39 frames left in this clip
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/NOTHING/NOTHING_7.mp4 with label NOTHING and 35 frames from 211 to 246
# There are 4 frames left in this clip
# Dropped label a run of NOTHING with 4 frames from 246 to 250
# Processing a run of 56 frames with label KICK_R
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/KICK_R/KICK_R_8.mp4 with label KICK_R and 35 frames from 250 to 285
# There are 21 frames left in this clip
# Dropped label a run of KICK_R with 21 frames from 285 to 306
# Processing a run of 67 frames with label NOTHING
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/NOTHING/NOTHING_9.mp4 with label NOTHING and 35 frames from 306 to 341
# There are 32 frames left in this clip
# Dropped label a run of NOTHING with 32 frames from 341 to 373
# Processing a run of 55 frames with label TACKLE_S
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/TACKLE_S/TACKLE_S_10.mp4 with label TACKLE_S and 35 frames from 373 to 408
# There are 20 frames left in this clip
# Dropped label a run of TACKLE_S with 20 frames from 408 to 428
# Processing a run of 71 frames with label RUCK
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/RUCK/RUCK_11.mp4 with label RUCK and 35 frames from 428 to 463
# There are 36 frames left in this clip
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/RUCK/RUCK_12.mp4 with label RUCK and 35 frames from 463 to 498
# There are 1 frames left in this clip
# Dropped label a run of RUCK with 1 frames from 498 to 499
# Processing a run of 14 frames with label PASS_L
# Dropped label a run of PASS_L with 14 frames from 499 to 513
# Processing a run of 19 frames with label CARRY
# Dropped label a run of CARRY with 19 frames from 513 to 532
# Processing a run of 25 frames with label TACKLE_S
# Dropped label a run of TACKLE_S with 25 frames from 532 to 557
# Processing a run of 231 frames with label RUCK
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/RUCK/RUCK_13.mp4 with label RUCK and 35 frames from 557 to 592
# There are 196 frames left in this clip
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/RUCK/RUCK_14.mp4 with label RUCK and 35 frames from 592 to 627
# There are 161 frames left in this clip
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/RUCK/RUCK_15.mp4 with label RUCK and 35 frames from 627 to 662
# There are 126 frames left in this clip
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/RUCK/RUCK_16.mp4 with label RUCK and 35 frames from 662 to 697
# There are 91 frames left in this clip
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/RUCK/RUCK_17.mp4 with label RUCK and 35 frames from 697 to 732
# There are 56 frames left in this clip
# Saved filename /dcs/large/u1901447/videos/clips/all_35_frames/RUCK/RUCK_18.mp4 with label RUCK and 35 frames from 732 to 767
# There are 21 frames left in this clip
# Dropped label a run of RUCK with 21 frames from 767 to 788
# Processing a run of 11 frames with label CARRY
# Dropped label a run of CARRY with 11 frames from 788 to 799
# Processing a run of 18 frames with label KICK_R
# Dropped label a run of KICK_R with 18 frames from 799 to 817
# Processing a run of 95 frames with label NOTHING
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 30
#      28 out = cv2.VideoWriter(videocap_name, cv2.VideoWriter_fourcc(*'mp4v'), fps, videodims)
#      29 for frame in frames:
# ---> 30     out.write(frame)
#      31 out.release()
#      32 print(f"Saved filename {videocap_name} with label {label} and {clip_length} frames from {frame_counter} to {frame_counter+clip_length}")
#
# KeyboardInterrupt:

# %% [markdown]
# This is a temporary solution that should be embedded in the code above.
# It copied files generated above into separate train/test/validation folders - and subfolders for each class inside those.
# This seems to be the defacto standard for tf/keras

# %%
clips_dir = r'/dcs/large/u1901447/videos/clips/all_35_frames'
dest_dir = r'/dcs/large/u1901447/videos/clips/data_35_frames'
# Make the folders if they dont exist
if not os.path.isdir(f"{dest_dir}"):
    os.mkdir(f"{dest_dir}")
if not os.path.isdir(f"{dest_dir}/val"):
    os.mkdir(f"{dest_dir}/val")
if not os.path.isdir(f"{dest_dir}/train"):
  os.mkdir(f"{dest_dir}/train")
if not os.path.isdir(f"{dest_dir}/test/{dir}"):
  os.mkdir(f"{dest_dir}/test")
# Define the proportions required in each collection
val_prop = 0.2
test_prop = 0.2
train_prop = 0.6
# Iterate the main directory folder
for root, dirs, files in os.walk(clips_dir):
    for dir in dirs:
      # Ignore any folders hidden with leading'.'
      if dir[0] == '.':
        continue
      else:
        # Iterate each Class folder, extracting a random set of file names from the folder
        # Val first, then test, and all that are left go into train
        for root2, dirs2, files2 in os.walk(f"{clips_dir}/{dir}"):
          full_files_set = set(files2)
          print(full_files_set)
          val_files = set(random.sample(full_files_set, int(len(full_files_set)*val_prop)))
          
          print(val_files)
          if not os.path.isdir(f"{dest_dir}/val/{dir}"):
            os.mkdir(f"{dest_dir}/val/{dir}")
          for file in val_files:
            # Source path
            source = f"{clips_dir}/{dir}/{file}"
            # Destination path
            destination = f"{dest_dir}/val/{dir}/{file}"
            # Move the content of source to destination
            dest = shutil.move(source, destination)
          rem_files = full_files_set - val_files
          test_files = set(random.sample(rem_files, int(len(full_files_set)*test_prop)))
          print(test_files)
          if not os.path.isdir(f"{dest_dir}/test/{dir}"):
            os.mkdir(f"{dest_dir}/test/{dir}")
          for file in test_files:
            # Source path
            source = f"{clips_dir}/{dir}/{file}"
            # Destination path
            destination = f"{dest_dir}/test/{dir}/{file}"
            # Move the content of source to destination
            dest = shutil.move(source, destination)
          train_files = rem_files - test_files
          print(train_files)
          if not os.path.isdir(f"{dest_dir}/train/{dir}"):
            os.mkdir(f"{dest_dir}/train/{dir}")
          for file in train_files:
            # Source path
            source = f"{clips_dir}/{dir}/{file}"
            # Destination path
            destination = f"{dest_dir}/train/{dir}/{file}"
            # Move the content of source to destination
            dest = shutil.move(source, destination)
# Out:
# {'TACKLE_S_D_2803.mp4', 'TACKLE_S_D_2802.mp4', 'TACKLE_S_D_3832.mp4', 'TACKLE_S_D_1667.mp4', 'TACKLE_S_D_633.mp4'}
# {'TACKLE_S_D_2803.mp4'}
# {'TACKLE_S_D_3832.mp4'}
# {'TACKLE_S_D_633.mp4', 'TACKLE_S_D_2802.mp4', 'TACKLE_S_D_1667.mp4'}
# {'PASS_L_1230.mp4', 'PASS_L_3031.mp4', 'PASS_L_1839.mp4', 'PASS_L_3829.mp4', 'PASS_L_1849.mp4', 'PASS_L_820.mp4'}
# {'PASS_L_3031.mp4'}
# {'PASS_L_3829.mp4'}
# {'PASS_L_1230.mp4', 'PASS_L_820.mp4', 'PASS_L_1839.mp4', 'PASS_L_1849.mp4'}
# {'CARRY_1795.mp4', 'CARRY_129.mp4', 'CARRY_1853.mp4', 'CARRY_3671.mp4', 'CARRY_3747.mp4', 'CARRY_2960.mp4', 'CARRY_2991.mp4', 'CARRY_638.mp4', 'CARRY_719.mp4', 'CARRY_1089.mp4', 'CARRY_1662.mp4', 'CARRY_465.mp4', 'CARRY_3354.mp4', 'CARRY_718.mp4', 'CARRY_2891.mp4', 'CARRY_796.mp4', 'CARRY_3356.mp4', 'CARRY_1649.mp4', 'CARRY_3571.mp4', 'CARRY_2861.mp4', 'CARRY_4257.mp4', 'CARRY_406.mp4', 'CARRY_3243.mp4', 'CARRY_21.mp4', 'CARRY_1095.mp4', 'CARRY_2862.mp4', 'CARRY_474.mp4', 'CARRY_717.mp4', 'CARRY_3257.mp4', 'CARRY_3039.mp4', 'CARRY_2865.mp4', 'CARRY_604.mp4', 'CARRY_1309.mp4', 'CARRY_3242.mp4', 'CARRY_1360.mp4', 'CARRY_3955.mp4', 'CARRY_475.mp4', 'CARRY_4391.mp4', 'CARRY_3249.mp4', 'CARRY_1852.mp4', 'CARRY_1842.mp4', 'CARRY_1316.mp4', 'CARRY_3979.mp4', 'CARRY_407.mp4', 'CARRY_2804.mp4', 'CARRY_3240.mp4', 'CARRY_1317.mp4', 'CARRY_1228.mp4', 'CARRY_2892.mp4', 'CARRY_134.mp4', 'CARRY_4258.mp4', 'CARRY_2888.mp4', 'CARRY_3131.mp4', 'CARRY_1086.mp4', 'CARRY_1365.mp4', 'CARRY_4089.mp4', 'CARRY_1647.mp4', 'CARRY_3234.mp4', 'CARRY_3032.mp4', 'CARRY_1363.mp4', 'CARRY_3355.mp4', 'CARRY_1229.mp4', 'CARRY_630.mp4', 'CARRY_3255.mp4', 'CARRY_634.mp4', 'CARRY_2893.mp4', 'CARRY_4086.mp4', 'CARRY_3745.mp4', 'CARRY_605.mp4', 'CARRY_228.mp4', 'CARRY_476.mp4', 'CARRY_3038.mp4', 'CARRY_2895.mp4', 'CARRY_3248.mp4', 'CARRY_3241.mp4', 'CARRY_3256.mp4', 'CARRY_3025.mp4', 'CARRY_1862.mp4', 'CARRY_3444.mp4', 'CARRY_2992.mp4', 'CARRY_4090.mp4', 'CARRY_3949.mp4', 'CARRY_3852.mp4', 'CARRY_3669.mp4', 'CARRY_4087.mp4', 'CARRY_997.mp4', 'CARRY_3438.mp4', 'CARRY_4078.mp4', 'CARRY_3251.mp4', 'CARRY_333.mp4', 'CARRY_2808.mp4', 'CARRY_1307.mp4', 'CARRY_3952.mp4', 'CARRY_3670.mp4', 'CARRY_606.mp4', 'CARRY_131.mp4', 'CARRY_130.mp4', 'CARRY_1364.mp4', 'CARRY_3441.mp4', 'CARRY_2874.mp4', 'CARRY_1861.mp4', 'CARRY_3623.mp4', 'CARRY_2875.mp4', 'CARRY_637.mp4', 'CARRY_3128.mp4', 'CARRY_3351.mp4', 'CARRY_1494.mp4', 'CARRY_4091.mp4'}
# {'CARRY_2991.mp4', 'CARRY_1316.mp4', 'CARRY_638.mp4', 'CARRY_1089.mp4', 'CARRY_4086.mp4', 'CARRY_718.mp4', 'CARRY_796.mp4', 'CARRY_130.mp4', 'CARRY_1228.mp4', 'CARRY_1649.mp4', 'CARRY_1364.mp4', 'CARRY_3248.mp4', 'CARRY_3243.mp4', 'CARRY_1095.mp4', 'CARRY_1861.mp4', 'CARRY_3257.mp4', 'CARRY_2865.mp4', 'CARRY_3444.mp4', 'CARRY_3131.mp4', 'CARRY_1647.mp4', 'CARRY_3251.mp4'}
# {'CARRY_1853.mp4', 'CARRY_465.mp4', 'CARRY_3354.mp4', 'CARRY_2804.mp4', 'CARRY_3670.mp4', 'CARRY_606.mp4', 'CARRY_131.mp4', 'CARRY_2891.mp4', 'CARRY_605.mp4', 'CARRY_2892.mp4', 'CARRY_3571.mp4', 'CARRY_2895.mp4', 'CARRY_4257.mp4', 'CARRY_2874.mp4', 'CARRY_3025.mp4', 'CARRY_4258.mp4', 'CARRY_637.mp4', 'CARRY_4087.mp4', 'CARRY_1360.mp4', 'CARRY_3234.mp4', 'CARRY_333.mp4'}
# {'CARRY_1795.mp4', 'CARRY_475.mp4', 'CARRY_129.mp4', 'CARRY_1363.mp4', 'CARRY_3355.mp4', 'CARRY_4391.mp4', 'CARRY_3249.mp4', 'CARRY_1852.mp4', 'CARRY_1229.mp4', 'CARRY_3671.mp4', 'CARRY_1842.mp4', 'CARRY_2808.mp4', 'CARRY_3747.mp4', 'CARRY_2960.mp4', 'CARRY_1307.mp4', 'CARRY_630.mp4', 'CARRY_719.mp4', 'CARRY_3979.mp4', 'CARRY_1662.mp4', 'CARRY_3255.mp4', 'CARRY_634.mp4', 'CARRY_407.mp4', 'CARRY_2893.mp4', 'CARRY_3952.mp4', 'CARRY_3240.mp4', 'CARRY_1317.mp4', 'CARRY_4078.mp4', 'CARRY_3745.mp4', 'CARRY_228.mp4', 'CARRY_3356.mp4', 'CARRY_134.mp4', 'CARRY_476.mp4', 'CARRY_2861.mp4', 'CARRY_3038.mp4', 'CARRY_3441.mp4', 'CARRY_406.mp4', 'CARRY_21.mp4', 'CARRY_3241.mp4', 'CARRY_3623.mp4', 'CARRY_2862.mp4', 'CARRY_474.mp4', 'CARRY_717.mp4', 'CARRY_3256.mp4', 'CARRY_3039.mp4', 'CARRY_2888.mp4', 'CARRY_2875.mp4', 'CARRY_3128.mp4', 'CARRY_1862.mp4', 'CARRY_2992.mp4', 'CARRY_3351.mp4', 'CARRY_4090.mp4', 'CARRY_604.mp4', 'CARRY_3949.mp4', 'CARRY_1309.mp4', 'CARRY_3955.mp4', 'CARRY_1494.mp4', 'CARRY_3852.mp4', 'CARRY_3669.mp4', 'CARRY_1086.mp4', 'CARRY_3242.mp4', 'CARRY_997.mp4', 'CARRY_3438.mp4', 'CARRY_1365.mp4', 'CARRY_4089.mp4', 'CARRY_3032.mp4', 'CARRY_4091.mp4'}
# {'TACKLE_D_1493.mp4', 'TACKLE_D_2101.mp4', 'TACKLE_D_2084.mp4', 'TACKLE_D_2053.mp4', 'TACKLE_D_2023.mp4', 'TACKLE_D_2026.mp4', 'TACKLE_D_2076.mp4', 'TACKLE_D_2001.mp4', 'TACKLE_D_2036.mp4', 'TACKLE_D_2098.mp4', 'TACKLE_D_2035.mp4', 'TACKLE_D_2069.mp4', 'TACKLE_D_2062.mp4', 'TACKLE_D_2022.mp4', 'TACKLE_D_2013.mp4', 'TACKLE_D_1982.mp4', 'TACKLE_D_405.mp4', 'TACKLE_D_2025.mp4', 'TACKLE_D_1984.mp4', 'TACKLE_D_2091.mp4', 'TACKLE_D_2010.mp4', 'TACKLE_D_2073.mp4', 'TACKLE_D_2088.mp4', 'TACKLE_D_2032.mp4', 'TACKLE_D_2003.mp4', 'TACKLE_D_990.mp4', 'TACKLE_D_1663.mp4', 'TACKLE_D_1991.mp4', 'TACKLE_D_1996.mp4', 'TACKLE_D_2066.mp4', 'TACKLE_D_2038.mp4', 'TACKLE_D_2016.mp4', 'TACKLE_D_2071.mp4', 'TACKLE_D_2014.mp4', 'TACKLE_D_1643.mp4', 'TACKLE_D_2064.mp4', 'TACKLE_D_2079.mp4', 'TACKLE_D_2008.mp4', 'TACKLE_D_2087.mp4', 'TACKLE_D_2044.mp4', 'TACKLE_D_2099.mp4', 'TACKLE_D_1993.mp4', 'TACKLE_D_3117.mp4', 'TACKLE_D_1990.mp4', 'TACKLE_D_2077.mp4', 'TACKLE_D_2092.mp4', 'TACKLE_D_2072.mp4', 'TACKLE_D_2096.mp4', 'TACKLE_D_2078.mp4', 'TACKLE_D_3238.mp4', 'TACKLE_D_2097.mp4', 'TACKLE_D_2019.mp4', 'TACKLE_D_2090.mp4', 'TACKLE_D_2085.mp4', 'TACKLE_D_4327.mp4', 'TACKLE_D_2086.mp4', 'TACKLE_D_3452.mp4', 'TACKLE_D_2028.mp4', 'TACKLE_D_2009.mp4', 'TACKLE_D_1995.mp4', 'TACKLE_D_1992.mp4', 'TACKLE_D_3433.mp4', 'TACKLE_D_1989.mp4', 'TACKLE_D_2083.mp4', 'TACKLE_D_2094.mp4', 'TACKLE_D_2061.mp4', 'TACKLE_D_2055.mp4', 'TACKLE_D_2100.mp4', 'TACKLE_D_2057.mp4', 'TACKLE_D_4247.mp4', 'TACKLE_D_1988.mp4', 'TACKLE_D_2005.mp4', 'TACKLE_D_2089.mp4', 'TACKLE_D_1980.mp4', 'TACKLE_D_2021.mp4', 'TACKLE_D_2081.mp4', 'TACKLE_D_2029.mp4', 'TACKLE_D_2002.mp4', 'TACKLE_D_3958.mp4', 'TACKLE_D_2060.mp4', 'TACKLE_D_2031.mp4', 'TACKLE_D_1987.mp4', 'TACKLE_D_2048.mp4', 'TACKLE_D_1983.mp4', 'TACKLE_D_2047.mp4', 'TACKLE_D_2065.mp4', 'TACKLE_D_1978.mp4', 'TACKLE_D_2017.mp4', 'TACKLE_D_2041.mp4', 'TACKLE_D_2037.mp4', 'TACKLE_D_2043.mp4', 'TACKLE_D_1977.mp4', 'TACKLE_D_1979.mp4', 'TACKLE_D_2059.mp4', 'TACKLE_D_4328.mp4', 'TACKLE_D_1997.mp4', 'TACKLE_D_1994.mp4', 'TACKLE_D_2058.mp4', 'TACKLE_D_2063.mp4', 'TACKLE_D_404.mp4', 'TACKLE_D_2068.mp4', 'TACKLE_D_2052.mp4', 'TACKLE_D_1986.mp4', 'TACKLE_D_3957.mp4', 'TACKLE_D_2027.mp4', 'TACKLE_D_2093.mp4', 'TACKLE_D_884.mp4', 'TACKLE_D_2080.mp4', 'TACKLE_D_2046.mp4', 'TACKLE_D_2030.mp4', 'TACKLE_D_2042.mp4', 'TACKLE_D_2074.mp4', 'TACKLE_D_2095.mp4', 'TACKLE_D_122.mp4', 'TACKLE_D_2006.mp4', 'TACKLE_D_403.mp4', 'TACKLE_D_1998.mp4', 'TACKLE_D_1846.mp4', 'TACKLE_D_1999.mp4', 'TACKLE_D_3028.mp4', 'TACKLE_D_2007.mp4', 'TACKLE_D_2012.mp4', 'TACKLE_D_2810.mp4', 'TACKLE_D_3034.mp4', 'TACKLE_D_2040.mp4', 'TACKLE_D_1981.mp4', 'TACKLE_D_2015.mp4', 'TACKLE_D_2033.mp4', 'TACKLE_D_124.mp4', 'TACKLE_D_2034.mp4', 'TACKLE_D_2039.mp4', 'TACKLE_D_2045.mp4', 'TACKLE_D_883.mp4', 'TACKLE_D_1087.mp4', 'TACKLE_D_2054.mp4', 'TACKLE_D_2049.mp4', 'TACKLE_D_2018.mp4', 'TACKLE_D_3959.mp4', 'TACKLE_D_680.mp4', 'TACKLE_D_2056.mp4', 'TACKLE_D_1974.mp4', 'TACKLE_D_2024.mp4', 'TACKLE_D_2004.mp4', 'TACKLE_D_1985.mp4', 'TACKLE_D_2051.mp4', 'TACKLE_D_2067.mp4', 'TACKLE_D_2050.mp4', 'TACKLE_D_1793.mp4', 'TACKLE_D_2000.mp4', 'TACKLE_D_2011.mp4', 'TACKLE_D_2082.mp4', 'TACKLE_D_812.mp4', 'TACKLE_D_2020.mp4', 'TACKLE_D_2075.mp4', 'TACKLE_D_3352.mp4', 'TACKLE_D_2070.mp4'}
# {'TACKLE_D_2096.mp4', 'TACKLE_D_2053.mp4', 'TACKLE_D_1978.mp4', 'TACKLE_D_2069.mp4', 'TACKLE_D_2035.mp4', 'TACKLE_D_2043.mp4', 'TACKLE_D_2022.mp4', 'TACKLE_D_2091.mp4', 'TACKLE_D_1977.mp4', 'TACKLE_D_3452.mp4', 'TACKLE_D_1979.mp4', 'TACKLE_D_2059.mp4', 'TACKLE_D_1997.mp4', 'TACKLE_D_2054.mp4', 'TACKLE_D_2063.mp4', 'TACKLE_D_404.mp4', 'TACKLE_D_2080.mp4', 'TACKLE_D_1991.mp4', 'TACKLE_D_1985.mp4', 'TACKLE_D_1980.mp4', 'TACKLE_D_2021.mp4', 'TACKLE_D_2006.mp4', 'TACKLE_D_1846.mp4', 'TACKLE_D_2002.mp4', 'TACKLE_D_3958.mp4', 'TACKLE_D_2064.mp4', 'TACKLE_D_3352.mp4', 'TACKLE_D_2099.mp4', 'TACKLE_D_1987.mp4', 'TACKLE_D_2092.mp4', 'TACKLE_D_2070.mp4'}
# {'TACKLE_D_2084.mp4', 'TACKLE_D_2810.mp4', 'TACKLE_D_2023.mp4', 'TACKLE_D_2034.mp4', 'TACKLE_D_2039.mp4', 'TACKLE_D_4327.mp4', 'TACKLE_D_2086.mp4', 'TACKLE_D_1984.mp4', 'TACKLE_D_1995.mp4', 'TACKLE_D_2058.mp4', 'TACKLE_D_2018.mp4', 'TACKLE_D_3433.mp4', 'TACKLE_D_1663.mp4', 'TACKLE_D_2052.mp4', 'TACKLE_D_1989.mp4', 'TACKLE_D_3957.mp4', 'TACKLE_D_2055.mp4', 'TACKLE_D_1974.mp4', 'TACKLE_D_2089.mp4', 'TACKLE_D_2038.mp4', 'TACKLE_D_2081.mp4', 'TACKLE_D_403.mp4', 'TACKLE_D_1998.mp4', 'TACKLE_D_2014.mp4', 'TACKLE_D_812.mp4', 'TACKLE_D_2082.mp4', 'TACKLE_D_2011.mp4', 'TACKLE_D_2079.mp4', 'TACKLE_D_2060.mp4', 'TACKLE_D_2031.mp4', 'TACKLE_D_3117.mp4'}
# {'TACKLE_D_1493.mp4', 'TACKLE_D_2101.mp4', 'TACKLE_D_2026.mp4', 'TACKLE_D_2076.mp4', 'TACKLE_D_2001.mp4', 'TACKLE_D_2036.mp4', 'TACKLE_D_2098.mp4', 'TACKLE_D_2062.mp4', 'TACKLE_D_405.mp4', 'TACKLE_D_2025.mp4', 'TACKLE_D_2013.mp4', 'TACKLE_D_1982.mp4', 'TACKLE_D_2010.mp4', 'TACKLE_D_2073.mp4', 'TACKLE_D_2088.mp4', 'TACKLE_D_2032.mp4', 'TACKLE_D_2003.mp4', 'TACKLE_D_990.mp4', 'TACKLE_D_1996.mp4', 'TACKLE_D_2066.mp4', 'TACKLE_D_2016.mp4', 'TACKLE_D_2071.mp4', 'TACKLE_D_1643.mp4', 'TACKLE_D_2008.mp4', 'TACKLE_D_2087.mp4', 'TACKLE_D_2044.mp4', 'TACKLE_D_1993.mp4', 'TACKLE_D_1990.mp4', 'TACKLE_D_2072.mp4', 'TACKLE_D_2077.mp4', 'TACKLE_D_2078.mp4', 'TACKLE_D_3238.mp4', 'TACKLE_D_2097.mp4', 'TACKLE_D_2019.mp4', 'TACKLE_D_2090.mp4', 'TACKLE_D_2085.mp4', 'TACKLE_D_2028.mp4', 'TACKLE_D_2009.mp4', 'TACKLE_D_1992.mp4', 'TACKLE_D_2083.mp4', 'TACKLE_D_2094.mp4', 'TACKLE_D_2061.mp4', 'TACKLE_D_2100.mp4', 'TACKLE_D_2057.mp4', 'TACKLE_D_4247.mp4', 'TACKLE_D_1988.mp4', 'TACKLE_D_2005.mp4', 'TACKLE_D_2029.mp4', 'TACKLE_D_2048.mp4', 'TACKLE_D_1983.mp4', 'TACKLE_D_2047.mp4', 'TACKLE_D_2065.mp4', 'TACKLE_D_2017.mp4', 'TACKLE_D_2041.mp4', 'TACKLE_D_2037.mp4', 'TACKLE_D_4328.mp4', 'TACKLE_D_1994.mp4', 'TACKLE_D_2068.mp4', 'TACKLE_D_1986.mp4', 'TACKLE_D_2027.mp4', 'TACKLE_D_2093.mp4', 'TACKLE_D_884.mp4', 'TACKLE_D_2046.mp4', 'TACKLE_D_2030.mp4', 'TACKLE_D_2042.mp4', 'TACKLE_D_2074.mp4', 'TACKLE_D_2095.mp4', 'TACKLE_D_122.mp4', 'TACKLE_D_1999.mp4', 'TACKLE_D_3028.mp4', 'TACKLE_D_2007.mp4', 'TACKLE_D_2012.mp4', 'TACKLE_D_1981.mp4', 'TACKLE_D_3034.mp4', 'TACKLE_D_2040.mp4', 'TACKLE_D_2015.mp4', 'TACKLE_D_2033.mp4', 'TACKLE_D_124.mp4', 'TACKLE_D_2045.mp4', 'TACKLE_D_883.mp4', 'TACKLE_D_1087.mp4', 'TACKLE_D_2049.mp4', 'TACKLE_D_3959.mp4', 'TACKLE_D_680.mp4', 'TACKLE_D_2056.mp4', 'TACKLE_D_2024.mp4', 'TACKLE_D_2004.mp4', 'TACKLE_D_2051.mp4', 'TACKLE_D_2067.mp4', 'TACKLE_D_2050.mp4', 'TACKLE_D_1793.mp4', 'TACKLE_D_2000.mp4', 'TACKLE_D_2075.mp4', 'TACKLE_D_2020.mp4'}
# /tmp/dcs-tmp.u1901447/ipykernel_148615/1345648885.py:28: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   val_files = set(random.sample(full_files_set, int(len(full_files_set)*val_prop)))
# /tmp/dcs-tmp.u1901447/ipykernel_148615/1345648885.py:40: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   test_files = set(random.sample(rem_files, int(len(full_files_set)*test_prop)))
# {'TACKLE_S_3026.mp4', 'TACKLE_S_3445.mp4', 'TACKLE_S_2815.mp4', 'TACKLE_S_4088.mp4', 'TACKLE_S_229.mp4', 'TACKLE_S_810.mp4', 'TACKLE_S_4377.mp4', 'TACKLE_S_3129.mp4', 'TACKLE_S_2896.mp4', 'TACKLE_S_4398.mp4', 'TACKLE_S_987.mp4', 'TACKLE_S_1094.mp4', 'TACKLE_S_22.mp4', 'TACKLE_S_4325.mp4', 'TACKLE_S_3247.mp4', 'TACKLE_S_1096.mp4', 'TACKLE_S_976.mp4', 'TACKLE_S_2993.mp4', 'TACKLE_S_635.mp4', 'TACKLE_S_998.mp4', 'TACKLE_S_4330.mp4', 'TACKLE_S_804.mp4', 'TACKLE_S_798.mp4', 'TACKLE_S_797.mp4', 'TACKLE_S_1854.mp4', 'TACKLE_S_3969.mp4', 'TACKLE_S_561.mp4', 'TACKLE_S_1970.mp4', 'TACKLE_S_1358.mp4', 'TACKLE_S_10.mp4', 'TACKLE_S_611.mp4', 'TACKLE_S_1840.mp4', 'TACKLE_S_608.mp4', 'TACKLE_S_1843.mp4', 'TACKLE_S_4085.mp4', 'TACKLE_S_2889.mp4', 'TACKLE_S_1090.mp4', 'TACKLE_S_3966.mp4', 'TACKLE_S_2869.mp4', 'TACKLE_S_4395.mp4', 'TACKLE_S_29.mp4', 'TACKLE_S_46.mp4', 'TACKLE_S_30.mp4', 'TACKLE_S_2876.mp4', 'TACKLE_S_33.mp4', 'TACKLE_S_1099.mp4', 'TACKLE_S_4084.mp4', 'TACKLE_S_1574.mp4', 'TACKLE_S_799.mp4', 'TACKLE_S_807.mp4', 'TACKLE_S_4376.mp4', 'TACKLE_S_3435.mp4', 'TACKLE_S_4154.mp4', 'TACKLE_S_3950.mp4', 'TACKLE_S_4561.mp4', 'TACKLE_S_2805.mp4', 'TACKLE_S_3853.mp4', 'TACKLE_S_3847.mp4', 'TACKLE_S_410.mp4', 'TACKLE_S_1648.mp4', 'TACKLE_S_806.mp4', 'TACKLE_S_2902.mp4', 'TACKLE_S_3235.mp4', 'TACKLE_S_2863.mp4', 'TACKLE_S_1097.mp4', 'TACKLE_S_4394.mp4', 'TACKLE_S_2866.mp4', 'TACKLE_S_4392.mp4', 'TACKLE_S_607.mp4', 'TACKLE_S_3956.mp4', 'TACKLE_S_4159.mp4', 'TACKLE_S_230.mp4'}
# {'TACKLE_S_3026.mp4', 'TACKLE_S_2869.mp4', 'TACKLE_S_1648.mp4', 'TACKLE_S_3853.mp4', 'TACKLE_S_4377.mp4', 'TACKLE_S_2876.mp4', 'TACKLE_S_33.mp4', 'TACKLE_S_1970.mp4', 'TACKLE_S_1358.mp4', 'TACKLE_S_22.mp4', 'TACKLE_S_1099.mp4', 'TACKLE_S_807.mp4', 'TACKLE_S_1843.mp4', 'TACKLE_S_4376.mp4'}
# {'TACKLE_S_3445.mp4', 'TACKLE_S_804.mp4', 'TACKLE_S_1097.mp4', 'TACKLE_S_797.mp4', 'TACKLE_S_2902.mp4', 'TACKLE_S_976.mp4', 'TACKLE_S_2896.mp4', 'TACKLE_S_561.mp4', 'TACKLE_S_4392.mp4', 'TACKLE_S_4325.mp4', 'TACKLE_S_608.mp4', 'TACKLE_S_4085.mp4', 'TACKLE_S_2993.mp4', 'TACKLE_S_4088.mp4'}
# {'TACKLE_S_2815.mp4', 'TACKLE_S_229.mp4', 'TACKLE_S_810.mp4', 'TACKLE_S_987.mp4', 'TACKLE_S_3129.mp4', 'TACKLE_S_4398.mp4', 'TACKLE_S_1094.mp4', 'TACKLE_S_3247.mp4', 'TACKLE_S_1096.mp4', 'TACKLE_S_635.mp4', 'TACKLE_S_998.mp4', 'TACKLE_S_4330.mp4', 'TACKLE_S_798.mp4', 'TACKLE_S_1854.mp4', 'TACKLE_S_3969.mp4', 'TACKLE_S_611.mp4', 'TACKLE_S_10.mp4', 'TACKLE_S_1840.mp4', 'TACKLE_S_2889.mp4', 'TACKLE_S_1090.mp4', 'TACKLE_S_3966.mp4', 'TACKLE_S_4395.mp4', 'TACKLE_S_29.mp4', 'TACKLE_S_46.mp4', 'TACKLE_S_30.mp4', 'TACKLE_S_799.mp4', 'TACKLE_S_4084.mp4', 'TACKLE_S_1574.mp4', 'TACKLE_S_4154.mp4', 'TACKLE_S_3435.mp4', 'TACKLE_S_3950.mp4', 'TACKLE_S_4561.mp4', 'TACKLE_S_2805.mp4', 'TACKLE_S_3847.mp4', 'TACKLE_S_410.mp4', 'TACKLE_S_806.mp4', 'TACKLE_S_3235.mp4', 'TACKLE_S_2863.mp4', 'TACKLE_S_4394.mp4', 'TACKLE_S_2866.mp4', 'TACKLE_S_607.mp4', 'TACKLE_S_3956.mp4', 'TACKLE_S_4159.mp4', 'TACKLE_S_230.mp4'}
# {'RUCK_3970.mp4', 'RUCK_3035.mp4', 'RUCK_4240.mp4', 'RUCK_3353.mp4', 'RUCK_329.mp4', 'RUCK_3841.mp4', 'RUCK_1091.mp4', 'RUCK_3250.mp4', 'RUCK_4164.mp4', 'RUCK_11.mp4', 'RUCK_3964.mp4', 'RUCK_2800.mp4', 'RUCK_885.mp4', 'RUCK_53.mp4', 'RUCK_3453.mp4', 'RUCK_988.mp4', 'RUCK_4384.mp4', 'RUCK_3963.mp4', 'RUCK_2879.mp4', 'RUCK_4141.mp4', 'RUCK_2864.mp4', 'RUCK_3029.mp4', 'RUCK_3849.mp4', 'RUCK_55.mp4', 'RUCK_127.mp4', 'RUCK_126.mp4', 'RUCK_2795.mp4', 'RUCK_4370.mp4', 'RUCK_1671.mp4', 'RUCK_1088.mp4', 'RUCK_31.mp4', 'RUCK_1971.mp4', 'RUCK_982.mp4', 'RUCK_467.mp4', 'RUCK_3604.mp4', 'RUCK_802.mp4', 'RUCK_4252.mp4', 'RUCK_4162.mp4', 'RUCK_4371.mp4', 'RUCK_2819.mp4', 'RUCK_1845.mp4', 'RUCK_36.mp4', 'RUCK_994.mp4', 'RUCK_3244.mp4', 'RUCK_2899.mp4', 'RUCK_3608.mp4', 'RUCK_1858.mp4', 'RUCK_18.mp4', 'RUCK_4231.mp4', 'RUCK_889.mp4', 'RUCK_4560.mp4', 'RUCK_2887.mp4', 'RUCK_3572.mp4', 'RUCK_1366.mp4', 'RUCK_989.mp4', 'RUCK_3845.mp4', 'RUCK_3456.mp4', 'RUCK_3612.mp4', 'RUCK_3449.mp4', 'RUCK_3977.mp4', 'RUCK_801.mp4', 'RUCK_4375.mp4', 'RUCK_3121.mp4', 'RUCK_1651.mp4', 'RUCK_3837.mp4', 'RUCK_3033.mp4', 'RUCK_1665.mp4', 'RUCK_3854.mp4', 'RUCK_4393.mp4', 'RUCK_4402.mp4', 'RUCK_610.mp4', 'RUCK_3614.mp4', 'RUCK_3030.mp4', 'RUCK_2811.mp4', 'RUCK_328.mp4', 'RUCK_1646.mp4', 'RUCK_35.mp4', 'RUCK_2867.mp4', 'RUCK_4558.mp4', 'RUCK_3580.mp4', 'RUCK_809.mp4', 'RUCK_123.mp4', 'RUCK_1002.mp4', 'RUCK_1656.mp4', 'RUCK_1660.mp4', 'RUCK_25.mp4', 'RUCK_631.mp4', 'RUCK_621.mp4', 'RUCK_1580.mp4', 'RUCK_1641.mp4', 'RUCK_4138.mp4', 'RUCK_2878.mp4', 'RUCK_3976.mp4', 'RUCK_1586.mp4', 'RUCK_3578.mp4', 'RUCK_4396.mp4', 'RUCK_4140.mp4', 'RUCK_3850.mp4', 'RUCK_4137.mp4', 'RUCK_3447.mp4', 'RUCK_3746.mp4', 'RUCK_632.mp4', 'RUCK_3960.mp4', 'RUCK_3252.mp4', 'RUCK_1359.mp4', 'RUCK_3114.mp4', 'RUCK_1973.mp4', 'RUCK_39.mp4', 'RUCK_1794.mp4', 'RUCK_814.mp4', 'RUCK_616.mp4', 'RUCK_1972.mp4', 'RUCK_48.mp4', 'RUCK_466.mp4', 'RUCK_1848.mp4', 'RUCK_4397.mp4', 'RUCK_636.mp4', 'RUCK_49.mp4', 'RUCK_4234.mp4', 'RUCK_888.mp4', 'RUCK_2806.mp4', 'RUCK_3610.mp4', 'RUCK_4144.mp4', 'RUCK_2904.mp4', 'RUCK_4158.mp4', 'RUCK_977.mp4', 'RUCK_1362.mp4', 'RUCK_625.mp4', 'RUCK_2816.mp4', 'RUCK_4399.mp4', 'RUCK_4166.mp4', 'RUCK_52.mp4', 'RUCK_4156.mp4', 'RUCK_3116.mp4', 'RUCK_2996.mp4', 'RUCK_2817.mp4', 'RUCK_4236.mp4', 'RUCK_3517.mp4', 'RUCK_999.mp4', 'RUCK_2797.mp4', 'RUCK_3436.mp4', 'RUCK_978.mp4', 'RUCK_4557.mp4', 'RUCK_816.mp4', 'RUCK_620.mp4', 'RUCK_50.mp4', 'RUCK_4157.mp4', 'RUCK_3458.mp4', 'RUCK_4253.mp4', 'RUCK_4160.mp4', 'RUCK_3848.mp4', 'RUCK_3967.mp4', 'RUCK_1100.mp4', 'RUCK_3118.mp4', 'RUCK_3833.mp4', 'RUCK_56.mp4', 'RUCK_1670.mp4', 'RUCK_3454.mp4', 'RUCK_609.mp4', 'RUCK_887.mp4', 'RUCK_4150.mp4', 'RUCK_2900.mp4', 'RUCK_980.mp4', 'RUCK_3253.mp4', 'RUCK_3947.mp4', 'RUCK_3575.mp4', 'RUCK_3237.mp4', 'RUCK_1098.mp4', 'RUCK_2807.mp4', 'RUCK_3036.mp4', 'RUCK_1661.mp4', 'RUCK_38.mp4', 'RUCK_4562.mp4', 'RUCK_4250.mp4', 'RUCK_4559.mp4', 'RUCK_3844.mp4', 'RUCK_3948.mp4', 'RUCK_808.mp4', 'RUCK_4564.mp4', 'RUCK_627.mp4', 'RUCK_1585.mp4', 'RUCK_4386.mp4', 'RUCK_1000.mp4', 'RUCK_3119.mp4', 'RUCK_4372.mp4', 'RUCK_1654.mp4', 'RUCK_979.mp4', 'RUCK_4146.mp4', 'RUCK_34.mp4', 'RUCK_1579.mp4', 'RUCK_128.mp4', 'RUCK_3125.mp4', 'RUCK_1645.mp4', 'RUCK_1650.mp4', 'RUCK_3965.mp4', 'RUCK_1658.mp4', 'RUCK_3236.mp4', 'RUCK_4165.mp4', 'RUCK_3576.mp4', 'RUCK_2881.mp4', 'RUCK_3037.mp4', 'RUCK_1581.mp4', 'RUCK_3607.mp4', 'RUCK_3843.mp4', 'RUCK_2897.mp4', 'RUCK_51.mp4', 'RUCK_12.mp4', 'RUCK_3968.mp4', 'RUCK_890.mp4', 'RUCK_4555.mp4', 'RUCK_3573.mp4', 'RUCK_3973.mp4', 'RUCK_3448.mp4', 'RUCK_3613.mp4', 'RUCK_3835.mp4', 'RUCK_622.mp4', 'RUCK_3124.mp4', 'RUCK_1860.mp4', 'RUCK_4239.mp4', 'RUCK_3971.mp4', 'RUCK_4145.mp4', 'RUCK_3123.mp4', 'RUCK_3842.mp4', 'RUCK_1850.mp4', 'RUCK_2799.mp4', 'RUCK_3615.mp4', 'RUCK_3446.mp4', 'RUCK_1863.mp4', 'RUCK_1644.mp4', 'RUCK_4385.mp4', 'RUCK_132.mp4', 'RUCK_4155.mp4', 'RUCK_1653.mp4', 'RUCK_1575.mp4', 'RUCK_4326.mp4', 'RUCK_818.mp4', 'RUCK_1657.mp4', 'RUCK_133.mp4', 'RUCK_993.mp4', 'RUCK_4382.mp4' ...
# {'RUCK_3970.mp4', 'RUCK_3035.mp4', 'RUCK_1581.mp4', 'RUCK_4138.mp4', 'RUCK_12.mp4', 'RUCK_3250.mp4', 'RUCK_3855.mp4', 'RUCK_37.mp4', 'RUCK_3448.mp4', 'RUCK_632.mp4', 'RUCK_3960.mp4', 'RUCK_4148.mp4', 'RUCK_3114.mp4', 'RUCK_2798.mp4', 'RUCK_1850.mp4', 'RUCK_57.mp4', 'RUCK_3849.mp4', 'RUCK_2795.mp4', 'RUCK_819.mp4', 'RUCK_4326.mp4', 'RUCK_1657.mp4', 'RUCK_3451.mp4', 'RUCK_886.mp4', 'RUCK_14.mp4', 'RUCK_1362.mp4', 'RUCK_982.mp4', 'RUCK_3579.mp4', 'RUCK_3972.mp4', 'RUCK_1844.mp4', 'RUCK_4378.mp4', 'RUCK_999.mp4', 'RUCK_2819.mp4', 'RUCK_1845.mp4', 'RUCK_978.mp4', 'RUCK_36.mp4', 'RUCK_50.mp4', 'RUCK_994.mp4', 'RUCK_2899.mp4', 'RUCK_3962.mp4', 'RUCK_4253.mp4', 'RUCK_1652.mp4', 'RUCK_3967.mp4', 'RUCK_18.mp4', 'RUCK_1670.mp4', 'RUCK_4161.mp4', 'RUCK_3254.mp4', 'RUCK_3845.mp4', 'RUCK_3253.mp4', 'RUCK_3027.mp4', 'RUCK_1098.mp4', 'RUCK_4381.mp4', 'RUCK_3121.mp4', 'RUCK_1651.mp4', 'RUCK_15.mp4', 'RUCK_4235.mp4', 'RUCK_4564.mp4', 'RUCK_3616.mp4', 'RUCK_4372.mp4', 'RUCK_3614.mp4', 'RUCK_3974.mp4', 'RUCK_35.mp4', 'RUCK_4143.mp4', 'RUCK_2867.mp4', 'RUCK_3580.mp4', 'RUCK_4558.mp4', 'RUCK_809.mp4', 'RUCK_1841.mp4', 'RUCK_128.mp4', 'RUCK_3840.mp4', 'RUCK_1645.mp4', 'RUCK_1577.mp4', 'RUCK_3965.mp4', 'RUCK_1576.mp4', 'RUCK_631.mp4', 'RUCK_2894.mp4', 'RUCK_621.mp4', 'RUCK_612.mp4'}
# {'RUCK_125.mp4', 'RUCK_4400.mp4', 'RUCK_4240.mp4', 'RUCK_3122.mp4', 'RUCK_2897.mp4', 'RUCK_3130.mp4', 'RUCK_326.mp4', 'RUCK_2878.mp4', 'RUCK_4555.mp4', 'RUCK_11.mp4', 'RUCK_4139.mp4', 'RUCK_4137.mp4', 'RUCK_1976.mp4', 'RUCK_3839.mp4', 'RUCK_3124.mp4', 'RUCK_4245.mp4', 'RUCK_814.mp4', 'RUCK_3123.mp4', 'RUCK_4141.mp4', 'RUCK_1848.mp4', 'RUCK_636.mp4', 'RUCK_3455.mp4', 'RUCK_1975.mp4', 'RUCK_4370.mp4', 'RUCK_888.mp4', 'RUCK_47.mp4', 'RUCK_4385.mp4', 'RUCK_132.mp4', 'RUCK_2806.mp4', 'RUCK_1653.mp4', 'RUCK_133.mp4', 'RUCK_993.mp4', 'RUCK_4238.mp4', 'RUCK_800.mp4', 'RUCK_3610.mp4', 'RUCK_1659.mp4', 'RUCK_2904.mp4', 'RUCK_42.mp4', 'RUCK_4383.mp4', 'RUCK_3450.mp4', 'RUCK_52.mp4', 'RUCK_4379.mp4', 'RUCK_4156.mp4', 'RUCK_4252.mp4', 'RUCK_4248.mp4', 'RUCK_2809.mp4', 'RUCK_4162.mp4', 'RUCK_2797.mp4', 'RUCK_1847.mp4', 'RUCK_4157.mp4', 'RUCK_4232.mp4', 'RUCK_3608.mp4', 'RUCK_1100.mp4', 'RUCK_813.mp4', 'RUCK_1642.mp4', 'RUCK_3454.mp4', 'RUCK_4403.mp4', 'RUCK_3605.mp4', 'RUCK_4556.mp4', 'RUCK_4375.mp4', 'RUCK_23.mp4', 'RUCK_3837.mp4', 'RUCK_4559.mp4', 'RUCK_3246.mp4', 'RUCK_1665.mp4', 'RUCK_3854.mp4', 'RUCK_3844.mp4', 'RUCK_3948.mp4', 'RUCK_330.mp4', 'RUCK_3961.mp4', 'RUCK_979.mp4', 'RUCK_4149.mp4', 'RUCK_1579.mp4', 'RUCK_1002.mp4', 'RUCK_3125.mp4', 'RUCK_25.mp4', 'RUCK_3236.mp4'}
# {'RUCK_3037.mp4', 'RUCK_1361.mp4', 'RUCK_2995.mp4', 'RUCK_1641.mp4', 'RUCK_3353.mp4', 'RUCK_3607.mp4', 'RUCK_1664.mp4', 'RUCK_3843.mp4', 'RUCK_3457.mp4', 'RUCK_329.mp4', 'RUCK_3841.mp4', 'RUCK_623.mp4', 'RUCK_51.mp4', 'RUCK_1091.mp4', 'RUCK_3968.mp4', 'RUCK_327.mp4', 'RUCK_3603.mp4', 'RUCK_4329.mp4', 'RUCK_3239.mp4', 'RUCK_890.mp4', 'RUCK_3573.mp4', 'RUCK_3976.mp4', 'RUCK_1495.mp4', 'RUCK_4164.mp4', 'RUCK_3973.mp4', 'RUCK_3964.mp4', 'RUCK_3577.mp4', 'RUCK_3838.mp4', 'RUCK_1586.mp4', 'RUCK_3846.mp4', 'RUCK_4374.mp4', 'RUCK_2800.mp4', 'RUCK_3578.mp4', 'RUCK_3613.mp4', 'RUCK_4396.mp4', 'RUCK_4140.mp4', 'RUCK_3850.mp4', 'RUCK_885.mp4', 'RUCK_615.mp4', 'RUCK_3835.mp4', 'RUCK_622.mp4', 'RUCK_53.mp4', 'RUCK_811.mp4', 'RUCK_1860.mp4', 'RUCK_3447.mp4', 'RUCK_3746.mp4', 'RUCK_4239.mp4', 'RUCK_3252.mp4', 'RUCK_1359.mp4', 'RUCK_3453.mp4', 'RUCK_988.mp4', 'RUCK_3971.mp4', 'RUCK_1973.mp4', 'RUCK_39.mp4', 'RUCK_4384.mp4', 'RUCK_4145.mp4', 'RUCK_3963.mp4', 'RUCK_1794.mp4', 'RUCK_616.mp4', 'RUCK_2879.mp4', 'RUCK_1972.mp4', 'RUCK_3842.mp4', 'RUCK_613.mp4', 'RUCK_48.mp4', 'RUCK_981.mp4', 'RUCK_466.mp4', 'RUCK_2864.mp4', 'RUCK_2799.mp4', 'RUCK_3029.mp4', 'RUCK_4397.mp4', 'RUCK_3615.mp4', 'RUCK_55.mp4', 'RUCK_127.mp4', 'RUCK_3446.mp4', 'RUCK_1863.mp4', 'RUCK_126.mp4', 'RUCK_4147.mp4', 'RUCK_49.mp4', 'RUCK_4234.mp4', 'RUCK_1644.mp4', 'RUCK_3434.mp4', 'RUCK_1671.mp4', 'RUCK_1088.mp4', 'RUCK_31.mp4', 'RUCK_4155.mp4', 'RUCK_1859.mp4', 'RUCK_1575.mp4', 'RUCK_818.mp4', 'RUCK_4165.mp4', 'RUCK_4382.mp4', 'RUCK_3606.mp4', 'RUCK_4144.mp4', 'RUCK_1855.mp4', 'RUCK_1971.mp4', 'RUCK_992.mp4', 'RUCK_4158.mp4', 'RUCK_977.mp4', 'RUCK_625.mp4', 'RUCK_3836.mp4', 'RUCK_467.mp4', 'RUCK_3604.mp4', 'RUCK_802.mp4', 'RUCK_2816.mp4', 'RUCK_4399.mp4', 'RUCK_2994.mp4', 'RUCK_4166.mp4', 'RUCK_54.mp4', 'RUCK_991.mp4', 'RUCK_3116.mp4', 'RUCK_2996.mp4', 'RUCK_1655.mp4', 'RUCK_32.mp4', 'RUCK_2817.mp4', 'RUCK_4236.mp4', 'RUCK_2901.mp4', 'RUCK_3517.mp4', 'RUCK_4371.mp4', 'RUCK_681.mp4', 'RUCK_3436.mp4', 'RUCK_3245.mp4', 'RUCK_4557.mp4', 'RUCK_1093.mp4', 'RUCK_816.mp4', 'RUCK_620.mp4', 'RUCK_619.mp4', 'RUCK_3244.mp4', 'RUCK_3459.mp4', 'RUCK_1856.mp4', 'RUCK_4249.mp4', 'RUCK_1578.mp4', 'RUCK_626.mp4', 'RUCK_3115.mp4', 'RUCK_4380.mp4', 'RUCK_2796.mp4', 'RUCK_16.mp4', 'RUCK_3574.mp4', 'RUCK_3458.mp4', 'RUCK_4160.mp4', 'RUCK_3848.mp4', 'RUCK_43.mp4', 'RUCK_3118.mp4', 'RUCK_3833.mp4', 'RUCK_2868.mp4', 'RUCK_1001.mp4', 'RUCK_1858.mp4', 'RUCK_3834.mp4', 'RUCK_13.mp4', 'RUCK_56.mp4', 'RUCK_4231.mp4', 'RUCK_889.mp4', 'RUCK_4560.mp4', 'RUCK_4150.mp4', 'RUCK_609.mp4', 'RUCK_887.mp4', 'RUCK_2900.mp4', 'RUCK_2887.mp4', 'RUCK_3572.mp4', 'RUCK_1366.mp4', 'RUCK_989.mp4', 'RUCK_3609.mp4', 'RUCK_4142.mp4', 'RUCK_2801.mp4', 'RUCK_980.mp4', 'RUCK_3456.mp4', 'RUCK_1582.mp4', 'RUCK_3612.mp4', 'RUCK_803.mp4', 'RUCK_3449.mp4', 'RUCK_3947.mp4', 'RUCK_3575.mp4', 'RUCK_3851.mp4', 'RUCK_3237.mp4', 'RUCK_3977.mp4', 'RUCK_2880.mp4', 'RUCK_2890.mp4', 'RUCK_801.mp4', 'RUCK_2807.mp4', 'RUCK_3036.mp4', 'RUCK_3120.mp4', 'RUCK_17.mp4', 'RUCK_3611.mp4', 'RUCK_1661.mp4', 'RUCK_38.mp4', 'RUCK_4562.mp4', 'RUCK_4237.mp4', 'RUCK_45.mp4', 'RUCK_4250.mp4', 'RUCK_2818.mp4', 'RUCK_3033.mp4', 'RUCK_4233.mp4', 'RUCK_627.mp4', 'RUCK_1857.mp4', 'RUCK_808.mp4', 'RUCK_1092.mp4', 'RUCK_4393.mp4', 'RUCK_4331.mp4', 'RUCK_2877.mp4', 'RUCK_817.mp4', 'RUCK_1585.mp4', 'RUCK_4402.mp4', 'RUCK_610.mp4', 'RUCK_4386.mp4', 'RUCK_1000.mp4', 'RUCK_3119.mp4', 'RUCK_4241.mp4', 'RUCK_1654.mp4', 'RUCK_4251.mp4', 'RUCK_614.mp4', 'RUCK_3030.mp4', 'RUCK_2811.mp4', 'RUCK_328.mp4', 'RUCK_1851.mp4', 'RUCK_4146.mp4', 'RUCK_1646.mp4', 'RUCK_2903.mp4', 'RUCK_3113.mp4', 'RUCK_34.mp4', 'RUCK_4401.mp4', 'RUCK_815.mp4', 'RUCK_24.mp4', 'RUCK_123.mp4', 'RUCK_1656.mp4', 'RUCK_2898.mp4', 'RUCK_1660.mp4', 'RUCK_1650.mp4', 'RUCK_1658.mp4', 'RUCK_4246.mp4', 'RUCK_4373.mp4', 'RUCK_624.mp4', 'RUCK_4163.mp4', 'RUCK_1580.mp4', 'RUCK_4563.mp4', 'RUCK_3576.mp4', 'RUCK_2881.mp4'}
# {'SCRUM_397.mp4', 'SCRUM_3224.mp4', 'SCRUM_1928.mp4', 'SCRUM_3229.mp4', 'SCRUM_1221.mp4', 'SCRUM_1933.mp4', 'SCRUM_4471.mp4', 'SCRUM_4319.mp4', 'SCRUM_3504.mp4', 'SCRUM_1788.mp4', 'SCRUM_388.mp4', 'SCRUM_1446.mp4', 'SCRUM_3514.mp4', 'SCRUM_1266.mp4', 'SCRUM_1924.mp4', 'SCRUM_4313.mp4', 'SCRUM_714.mp4', 'SCRUM_1490.mp4', 'SCRUM_712.mp4', 'SCRUM_3658.mp4', 'SCRUM_213.mp4', 'SCRUM_1224.mp4', 'SCRUM_1957.mp4', 'SCRUM_1959.mp4', 'SCRUM_556.mp4', 'SCRUM_3233.mp4', 'SCRUM_3223.mp4', 'SCRUM_1791.mp4', 'SCRUM_1932.mp4', 'SCRUM_1786.mp4', 'SCRUM_399.mp4', 'SCRUM_558.mp4', 'SCRUM_1966.mp4', 'SCRUM_212.mp4', 'SCRUM_443.mp4', 'SCRUM_389.mp4', 'SCRUM_214.mp4', 'SCRUM_710.mp4', 'SCRUM_4133.mp4', 'SCRUM_442.mp4', 'SCRUM_4470.mp4', 'SCRUM_3655.mp4', 'SCRUM_1960.mp4', 'SCRUM_553.mp4', 'SCRUM_3218.mp4', 'SCRUM_3221.mp4', 'SCRUM_1484.mp4', 'SCRUM_551.mp4', 'SCRUM_3506.mp4', 'SCRUM_1273.mp4', 'SCRUM_4323.mp4', 'SCRUM_1450.mp4', 'SCRUM_209.mp4', 'SCRUM_1931.mp4', 'SCRUM_1925.mp4', 'SCRUM_4126.mp4', 'SCRUM_3230.mp4', 'SCRUM_401.mp4', 'SCRUM_1270.mp4', 'SCRUM_1449.mp4', 'SCRUM_4464.mp4', 'SCRUM_1223.mp4', 'SCRUM_1787.mp4', 'SCRUM_3511.mp4', 'SCRUM_795.mp4', 'SCRUM_4318.mp4', 'SCRUM_792.mp4', 'SCRUM_715.mp4', 'SCRUM_1962.mp4', 'SCRUM_3512.mp4', 'SCRUM_1274.mp4', 'SCRUM_549.mp4', 'SCRUM_1781.mp4', 'SCRUM_554.mp4', 'SCRUM_208.mp4', 'SCRUM_1452.mp4', 'SCRUM_3231.mp4', 'SCRUM_1480.mp4', 'SCRUM_1265.mp4', 'SCRUM_1965.mp4', 'SCRUM_4129.mp4', 'SCRUM_1780.mp4', 'SCRUM_3222.mp4', 'SCRUM_1226.mp4', 'SCRUM_210.mp4', 'SCRUM_3657.mp4', 'SCRUM_1222.mp4', 'SCRUM_1779.mp4', 'SCRUM_4466.mp4', 'SCRUM_4127.mp4', 'SCRUM_550.mp4', 'SCRUM_1785.mp4', 'SCRUM_4135.mp4', 'SCRUM_1922.mp4', 'SCRUM_3515.mp4', 'SCRUM_1929.mp4', 'SCRUM_4134.mp4', 'SCRUM_391.mp4', 'SCRUM_393.mp4', 'SCRUM_392.mp4', 'SCRUM_1272.mp4', 'SCRUM_557.mp4', 'SCRUM_1478.mp4', 'SCRUM_1219.mp4', 'SCRUM_1225.mp4', 'SCRUM_3661.mp4', 'SCRUM_1778.mp4', 'SCRUM_4320.mp4', 'SCRUM_400.mp4', 'SCRUM_1789.mp4', 'SCRUM_1489.mp4', 'SCRUM_448.mp4', 'SCRUM_449.mp4', 'SCRUM_1227.mp4', 'SCRUM_4473.mp4', 'SCRUM_216.mp4', 'SCRUM_4475.mp4', 'SCRUM_1447.mp4', 'SCRUM_1790.mp4', 'SCRUM_4321.mp4', 'SCRUM_1268.mp4', 'SCRUM_4314.mp4', 'SCRUM_4322.mp4', 'SCRUM_402.mp4', 'SCRUM_716.mp4', 'SCRUM_207.mp4', 'SCRUM_3509.mp4', 'SCRUM_794.mp4', 'SCRUM_1923.mp4', 'SCRUM_441.mp4', 'SCRUM_3662.mp4', 'SCRUM_1958.mp4', 'SCRUM_3505.mp4', 'SCRUM_3664.mp4', 'SCRUM_1961.mp4', 'SCRUM_1491.mp4', 'SCRUM_791.mp4', 'SCRUM_1783.mp4', 'SCRUM_709.mp4', 'SCRUM_3220.mp4', 'SCRUM_4472.mp4', 'SCRUM_4312.mp4', 'SCRUM_1448.mp4', 'SCRUM_3668.mp4', 'SCRUM_211.mp4', 'SCRUM_3656.mp4', 'SCRUM_1264.mp4', 'SCRUM_4311.mp4', 'SCRUM_1479.mp4', 'SCRUM_1453.mp4', 'SCRUM_398.mp4', 'SCRUM_206.mp4', 'SCRUM_396.mp4', 'SCRUM_205.mp4', 'SCRUM_3665.mp4', 'SCRUM_1969.mp4', 'SCRUM_4469.mp4', 'SCRUM_1963.mp4', 'SCRUM_447.mp4', 'SCRUM_395.mp4', 'SCRUM_1792.mp4', 'SCRUM_4317.mp4', 'SCRUM_559.mp4', 'SCRUM_790.mp4', 'SCRUM_4132.mp4', 'SCRUM_390.mp4', 'SCRUM_3219.mp4', 'SCRUM_446.mp4', 'SCRUM_3667.mp4', 'SCRUM_1483.mp4', 'SCRUM_3228.mp4', 'SCRUM_445.mp4', 'SCRUM_3217.mp4', 'SCRUM_793.mp4', 'SCRUM_444.mp4', 'SCRUM_3232.mp4', 'SCRUM_3226.mp4', 'SCRUM_394.mp4', 'SCRUM_1486.mp4', 'SCRUM_1482.mp4', 'SCRUM_1488.mp4', 'SCRUM_1220.mp4', 'SCRUM_1269.mp4', 'SCRUM_4467.mp4', 'SCRUM_1964.mp4', 'SCRUM_1967.mp4', 'SCRUM_3507.mp4', 'SCRUM_3659.mp4', 'SCRUM_711.mp4', 'SCRUM_450.mp4', 'SCRUM_1784.mp4', 'SCRUM_1930.mp4', 'SCRUM_1267.mp4', 'SCRUM_1487.mp4', 'SCRUM_1926.mp4', 'SCRUM_3663.mp4', 'SCRUM_4315.mp4', 'SCRUM_4324.mp4', 'SCRUM_1782.mp4', 'SCRUM_1451.mp4', 'SCRUM_4316.mp4', 'SCRUM_552.mp4', 'SCRUM_4474.mp4', 'SCRUM_1481.mp4', 'SCRUM_3225.mp4', 'SCRUM_1485.mp4', 'SCRUM_1927.mp4', 'SCRUM_555.mp4', 'SCRUM_3508.mp4', 'SCRUM_4136.mp4', 'SCRUM_3660.mp4', 'SCRUM_713.mp4', 'SCRUM_4130.mp4', 'SCRUM_3666.mp4', 'SCRUM_215.mp4', 'SCRUM_3513.mp4', 'SCRUM_1271.mp4', 'SCRUM_3227.mp4', 'SCRUM_4131.mp4', 'SCRUM_548.mp4', 'SCRUM_1455.mp4', 'SCRUM_3510.mp4', 'SCRUM_1968.mp4', 'SCRUM_1492.mp4', 'SCRUM_4468.mp4', 'SCRUM_4128. ...
# {'SCRUM_4126.mp4', 'SCRUM_3228.mp4', 'SCRUM_3511.mp4', 'SCRUM_1923.mp4', 'SCRUM_3217.mp4', 'SCRUM_3504.mp4', 'SCRUM_549.mp4', 'SCRUM_791.mp4', 'SCRUM_1220.mp4', 'SCRUM_1452.mp4', 'SCRUM_3514.mp4', 'SCRUM_4313.mp4', 'SCRUM_712.mp4', 'SCRUM_711.mp4', 'SCRUM_4472.mp4', 'SCRUM_4312.mp4', 'SCRUM_1224.mp4', 'SCRUM_1930.mp4', 'SCRUM_1226.mp4', 'SCRUM_210.mp4', 'SCRUM_4466.mp4', 'SCRUM_4315.mp4', 'SCRUM_4127.mp4', 'SCRUM_1479.mp4', 'SCRUM_1451.mp4', 'SCRUM_4316.mp4', 'SCRUM_212.mp4', 'SCRUM_396.mp4', 'SCRUM_555.mp4', 'SCRUM_1219.mp4', 'SCRUM_713.mp4', 'SCRUM_1778.mp4', 'SCRUM_710.mp4', 'SCRUM_3666.mp4', 'SCRUM_215.mp4', 'SCRUM_1792.mp4', 'SCRUM_3227.mp4', 'SCRUM_4475.mp4', 'SCRUM_3506.mp4', 'SCRUM_1450.mp4', 'SCRUM_1273.mp4', 'SCRUM_1492.mp4', 'SCRUM_4128.mp4', 'SCRUM_1268.mp4', 'SCRUM_1449.mp4'}
# {'SCRUM_3509.mp4', 'SCRUM_397.mp4', 'SCRUM_3224.mp4', 'SCRUM_4318.mp4', 'SCRUM_445.mp4', 'SCRUM_1933.mp4', 'SCRUM_394.mp4', 'SCRUM_4464.mp4', 'SCRUM_1274.mp4', 'SCRUM_3505.mp4', 'SCRUM_1488.mp4', 'SCRUM_1446.mp4', 'SCRUM_554.mp4', 'SCRUM_1266.mp4', 'SCRUM_4467.mp4', 'SCRUM_1967.mp4', 'SCRUM_1964.mp4', 'SCRUM_4129.mp4', 'SCRUM_1784.mp4', 'SCRUM_211.mp4', 'SCRUM_1957.mp4', 'SCRUM_3656.mp4', 'SCRUM_3223.mp4', 'SCRUM_4324.mp4', 'SCRUM_1929.mp4', 'SCRUM_398.mp4', 'SCRUM_205.mp4', 'SCRUM_443.mp4', 'SCRUM_4136.mp4', 'SCRUM_389.mp4', 'SCRUM_1963.mp4', 'SCRUM_214.mp4', 'SCRUM_4320.mp4', 'SCRUM_442.mp4', 'SCRUM_1271.mp4', 'SCRUM_3655.mp4', 'SCRUM_553.mp4', 'SCRUM_1455.mp4', 'SCRUM_551.mp4', 'SCRUM_1447.mp4', 'SCRUM_3510.mp4', 'SCRUM_4132.mp4', 'SCRUM_390.mp4', 'SCRUM_4321.mp4', 'SCRUM_1454.mp4'}
# {'SCRUM_1928.mp4', 'SCRUM_3229.mp4', 'SCRUM_1221.mp4', 'SCRUM_4471.mp4', 'SCRUM_4319.mp4', 'SCRUM_1788.mp4', 'SCRUM_388.mp4', 'SCRUM_1924.mp4', 'SCRUM_714.mp4', 'SCRUM_1490.mp4', 'SCRUM_3658.mp4', 'SCRUM_213.mp4', 'SCRUM_556.mp4', 'SCRUM_1959.mp4', 'SCRUM_3233.mp4', 'SCRUM_1791.mp4', 'SCRUM_1932.mp4', 'SCRUM_1786.mp4', 'SCRUM_399.mp4', 'SCRUM_558.mp4', 'SCRUM_1966.mp4', 'SCRUM_4133.mp4', 'SCRUM_4470.mp4', 'SCRUM_1960.mp4', 'SCRUM_3218.mp4', 'SCRUM_3221.mp4', 'SCRUM_1484.mp4', 'SCRUM_4323.mp4', 'SCRUM_209.mp4', 'SCRUM_1931.mp4', 'SCRUM_1925.mp4', 'SCRUM_3230.mp4', 'SCRUM_401.mp4', 'SCRUM_1270.mp4', 'SCRUM_1223.mp4', 'SCRUM_1787.mp4', 'SCRUM_795.mp4', 'SCRUM_715.mp4', 'SCRUM_792.mp4', 'SCRUM_1962.mp4', 'SCRUM_3512.mp4', 'SCRUM_1781.mp4', 'SCRUM_208.mp4', 'SCRUM_3231.mp4', 'SCRUM_1480.mp4', 'SCRUM_1265.mp4', 'SCRUM_1965.mp4', 'SCRUM_1780.mp4', 'SCRUM_3222.mp4', 'SCRUM_3657.mp4', 'SCRUM_1222.mp4', 'SCRUM_1779.mp4', 'SCRUM_550.mp4', 'SCRUM_1785.mp4', 'SCRUM_4135.mp4', 'SCRUM_1922.mp4', 'SCRUM_3515.mp4', 'SCRUM_4134.mp4', 'SCRUM_391.mp4', 'SCRUM_393.mp4', 'SCRUM_392.mp4', 'SCRUM_1272.mp4', 'SCRUM_557.mp4', 'SCRUM_1478.mp4', 'SCRUM_1225.mp4', 'SCRUM_3661.mp4', 'SCRUM_1789.mp4', 'SCRUM_1489.mp4', 'SCRUM_400.mp4', 'SCRUM_448.mp4', 'SCRUM_449.mp4', 'SCRUM_1227.mp4', 'SCRUM_4473.mp4', 'SCRUM_216.mp4', 'SCRUM_1790.mp4', 'SCRUM_4314.mp4', 'SCRUM_4322.mp4', 'SCRUM_402.mp4', 'SCRUM_716.mp4', 'SCRUM_207.mp4', 'SCRUM_794.mp4', 'SCRUM_441.mp4', 'SCRUM_3662.mp4', 'SCRUM_1958.mp4', 'SCRUM_3664.mp4', 'SCRUM_1961.mp4', 'SCRUM_1491.mp4', 'SCRUM_1783.mp4', 'SCRUM_709.mp4', 'SCRUM_3220.mp4', 'SCRUM_1448.mp4', 'SCRUM_3668.mp4', 'SCRUM_1264.mp4', 'SCRUM_4311.mp4', 'SCRUM_1453.mp4', 'SCRUM_206.mp4', 'SCRUM_3665.mp4', 'SCRUM_1969.mp4', 'SCRUM_4469.mp4', 'SCRUM_447.mp4', 'SCRUM_395.mp4', 'SCRUM_4317.mp4', 'SCRUM_559.mp4', 'SCRUM_790.mp4', 'SCRUM_3219.mp4', 'SCRUM_446.mp4', 'SCRUM_3667.mp4', 'SCRUM_1483.mp4', 'SCRUM_793.mp4', 'SCRUM_444.mp4', 'SCRUM_3232.mp4', 'SCRUM_3226.mp4', 'SCRUM_1486.mp4', 'SCRUM_1482.mp4', 'SCRUM_1269.mp4', 'SCRUM_3507.mp4', 'SCRUM_3659.mp4', 'SCRUM_450.mp4', 'SCRUM_1267.mp4', 'SCRUM_1487.mp4', 'SCRUM_1926.mp4', 'SCRUM_3663.mp4', 'SCRUM_1782.mp4', 'SCRUM_552.mp4', 'SCRUM_4474.mp4', 'SCRUM_1481.mp4', 'SCRUM_3225.mp4', 'SCRUM_1485.mp4', 'SCRUM_1927.mp4', 'SCRUM_3508.mp4', 'SCRUM_3660.mp4', 'SCRUM_4130.mp4', 'SCRUM_3513.mp4', 'SCRUM_4131.mp4', 'SCRUM_548.mp4', 'SCRUM_1968.mp4', 'SCRUM_4468.mp4', 'SCRUM_4465.mp4'}
# {'MAUL_2856.mp4', 'MAUL_176.mp4', 'MAUL_363.mp4', 'MAUL_364.mp4', 'MAUL_749.mp4', 'MAUL_878.mp4', 'MAUL_876.mp4', 'MAUL_880.mp4', 'MAUL_361.mp4', 'MAUL_362.mp4', 'MAUL_2956.mp4', 'MAUL_2852.mp4', 'MAUL_747.mp4', 'MAUL_2857.mp4', 'MAUL_3350.mp4', 'MAUL_746.mp4', 'MAUL_2952.mp4', 'MAUL_2853.mp4', 'MAUL_881.mp4', 'MAUL_366.mp4', 'MAUL_177.mp4', 'MAUL_875.mp4', 'MAUL_751.mp4', 'MAUL_2954.mp4', 'MAUL_2955.mp4', 'MAUL_2855.mp4', 'MAUL_753.mp4', 'MAUL_325.mp4', 'MAUL_750.mp4', 'MAUL_2851.mp4', 'MAUL_752.mp4', 'MAUL_679.mp4', 'MAUL_748.mp4', 'MAUL_178.mp4', 'MAUL_879.mp4', 'MAUL_180.mp4', 'MAUL_877.mp4', 'MAUL_2953.mp4', 'MAUL_882.mp4', 'MAUL_324.mp4', 'MAUL_2854.mp4', 'MAUL_2957.mp4', 'MAUL_181.mp4', 'MAUL_179.mp4', 'MAUL_367.mp4', 'MAUL_2794.mp4', 'MAUL_365.mp4'}
# {'MAUL_748.mp4', 'MAUL_879.mp4', 'MAUL_178.mp4', 'MAUL_882.mp4', 'MAUL_2952.mp4', 'MAUL_2957.mp4', 'MAUL_367.mp4', 'MAUL_752.mp4', 'MAUL_365.mp4'}
# {'MAUL_875.mp4', 'MAUL_751.mp4', 'MAUL_3350.mp4', 'MAUL_324.mp4', 'MAUL_177.mp4', 'MAUL_362.mp4', 'MAUL_2851.mp4', 'MAUL_2852.mp4', 'MAUL_179.mp4'}
# {'MAUL_2856.mp4', 'MAUL_176.mp4', 'MAUL_363.mp4', 'MAUL_364.mp4', 'MAUL_749.mp4', 'MAUL_878.mp4', 'MAUL_876.mp4', 'MAUL_880.mp4', 'MAUL_361.mp4', 'MAUL_2956.mp4', 'MAUL_747.mp4', 'MAUL_2857.mp4', 'MAUL_746.mp4', 'MAUL_2853.mp4', 'MAUL_881.mp4', 'MAUL_366.mp4', 'MAUL_2954.mp4', 'MAUL_2955.mp4', 'MAUL_2855.mp4', 'MAUL_753.mp4', 'MAUL_325.mp4', 'MAUL_750.mp4', 'MAUL_679.mp4', 'MAUL_180.mp4', 'MAUL_877.mp4', 'MAUL_2953.mp4', 'MAUL_2854.mp4', 'MAUL_181.mp4', 'MAUL_2794.mp4'}
# {'PASS_R_331.mp4', 'PASS_R_1313.mp4', 'PASS_R_805.mp4', 'PASS_R_3978.mp4', 'PASS_R_1666.mp4'}
# {'PASS_R_331.mp4'}
# {'PASS_R_805.mp4'}
# {'PASS_R_3978.mp4', 'PASS_R_1313.mp4', 'PASS_R_1666.mp4'}
# {'LINEOUT_1639.mp4', 'LINEOUT_3602.mp4', 'LINEOUT_1838.mp4', 'LINEOUT_745.mp4', 'LINEOUT_1082.mp4', 'LINEOUT_602.mp4', 'LINEOUT_678.mp4', 'LINEOUT_1822.mp4', 'LINEOUT_3022.mp4', 'LINEOUT_744.mp4', 'LINEOUT_1342.mp4', 'LINEOUT_1825.mp4', 'LINEOUT_1837.mp4', 'LINEOUT_3024.mp4', 'LINEOUT_1823.mp4', 'LINEOUT_3021.mp4', 'LINEOUT_3349.mp4', 'LINEOUT_1340.mp4', 'LINEOUT_1836.mp4', 'LINEOUT_3601.mp4', 'LINEOUT_1341.mp4', 'LINEOUT_1344.mp4', 'LINEOUT_1824.mp4', 'LINEOUT_1827.mp4', 'LINEOUT_873.mp4', 'LINEOUT_173.mp4', 'LINEOUT_1081.mp4', 'LINEOUT_360.mp4', 'LINEOUT_2848.mp4', 'LINEOUT_2948.mp4', 'LINEOUT_742.mp4', 'LINEOUT_4189.mp4', 'LINEOUT_1640.mp4', 'LINEOUT_2990.mp4', 'LINEOUT_4191.mp4', 'LINEOUT_3023.mp4', 'LINEOUT_2949.mp4', 'LINEOUT_743.mp4', 'LINEOUT_175.mp4', 'LINEOUT_1085.mp4', 'LINEOUT_1828.mp4', 'LINEOUT_1638.mp4', 'LINEOUT_4190.mp4', 'LINEOUT_677.mp4', 'LINEOUT_1343.mp4', 'LINEOUT_121.mp4', 'LINEOUT_2950.mp4', 'LINEOUT_2951.mp4', 'LINEOUT_601.mp4', 'LINEOUT_1826.mp4', 'LINEOUT_1083.mp4', 'LINEOUT_2850.mp4', 'LINEOUT_1304.mp4', 'LINEOUT_174.mp4', 'LINEOUT_2849.mp4', 'LINEOUT_874.mp4', 'LINEOUT_1084.mp4', 'LINEOUT_4188.mp4'}
# {'LINEOUT_1340.mp4', 'LINEOUT_2951.mp4', 'LINEOUT_4191.mp4', 'LINEOUT_3023.mp4', 'LINEOUT_1822.mp4', 'LINEOUT_1085.mp4', 'LINEOUT_1304.mp4', 'LINEOUT_1827.mp4', 'LINEOUT_121.mp4', 'LINEOUT_678.mp4', 'LINEOUT_3349.mp4'}
# {'LINEOUT_1838.mp4', 'LINEOUT_1083.mp4', 'LINEOUT_4189.mp4', 'LINEOUT_3601.mp4', 'LINEOUT_175.mp4', 'LINEOUT_173.mp4', 'LINEOUT_1824.mp4', 'LINEOUT_677.mp4', 'LINEOUT_1823.mp4', 'LINEOUT_874.mp4', 'LINEOUT_602.mp4'}
# {'LINEOUT_1639.mp4', 'LINEOUT_3602.mp4', 'LINEOUT_745.mp4', 'LINEOUT_1082.mp4', 'LINEOUT_744.mp4', 'LINEOUT_3022.mp4', 'LINEOUT_1342.mp4', 'LINEOUT_1825.mp4', 'LINEOUT_1837.mp4', 'LINEOUT_3024.mp4', 'LINEOUT_3021.mp4', 'LINEOUT_1836.mp4', 'LINEOUT_1341.mp4', 'LINEOUT_1344.mp4', 'LINEOUT_873.mp4', 'LINEOUT_1081.mp4', 'LINEOUT_360.mp4', 'LINEOUT_2848.mp4', 'LINEOUT_2948.mp4', 'LINEOUT_742.mp4', 'LINEOUT_1640.mp4', 'LINEOUT_2990.mp4', 'LINEOUT_2949.mp4', 'LINEOUT_1638.mp4', 'LINEOUT_743.mp4', 'LINEOUT_1828.mp4', 'LINEOUT_4190.mp4', 'LINEOUT_1343.mp4', 'LINEOUT_2950.mp4', 'LINEOUT_601.mp4', 'LINEOUT_1826.mp4', 'LINEOUT_2850.mp4', 'LINEOUT_174.mp4', 'LINEOUT_2849.mp4', 'LINEOUT_1084.mp4', 'LINEOUT_4188.mp4'}
# {'TACKLE_D_D_3954.mp4', 'TACKLE_D_D_3975.mp4', 'TACKLE_D_D_44.mp4', 'TACKLE_D_D_3953.mp4'}
# set()
# set()
# {'TACKLE_D_D_3954.mp4', 'TACKLE_D_D_3975.mp4', 'TACKLE_D_D_44.mp4', 'TACKLE_D_D_3953.mp4'}
# {'KICK_R_2830.mp4', 'KICK_R_3581.mp4', 'KICK_R_1812.mp4', 'KICK_R_3816.mp4', 'KICK_R_1543.mp4', 'KICK_R_983.mp4', 'KICK_R_3326.mp4', 'KICK_R_973.mp4', 'KICK_R_3110.mp4', 'KICK_R_322.mp4', 'KICK_R_4228.mp4', 'KICK_R_3410.mp4', 'KICK_R_4039.mp4', 'KICK_R_3431.mp4', 'KICK_R_3912.mp4', 'KICK_R_4387.mp4', 'KICK_R_151.mp4', 'KICK_R_2791.mp4', 'KICK_R_4332.mp4', 'KICK_R_2931.mp4', 'KICK_R_4566.mp4', 'KICK_R_3437.mp4', 'KICK_R_3941.mp4', 'KICK_R_1583.mp4', 'KICK_R_3083.mp4', 'KICK_R_1068.mp4', 'KICK_R_3112.mp4', 'KICK_R_460.mp4', 'KICK_R_4565.mp4', 'KICK_R_3442.mp4', 'KICK_R_1318.mp4', 'KICK_R_4567.mp4', 'KICK_R_954.mp4', 'KICK_R_995.mp4', 'KICK_R_4368.mp4', 'KICK_R_58.mp4', 'KICK_R_332.mp4', 'KICK_R_664.mp4', 'KICK_R_4538.mp4', 'KICK_R_3439.mp4', 'KICK_R_3126.mp4', 'KICK_R_4075.mp4', 'KICK_R_1572.mp4', 'KICK_R_225.mp4', 'KICK_R_3742.mp4', 'KICK_R_305.mp4', 'KICK_R_586.mp4', 'KICK_R_1588.mp4', 'KICK_R_8.mp4', 'KICK_R_3082.mp4', 'KICK_R_3553.mp4', 'KICK_R_1314.mp4', 'KICK_R_4568.mp4', 'KICK_R_1355.mp4', 'KICK_R_337.mp4', 'KICK_R_2961.mp4', 'KICK_R_152.mp4', 'KICK_R_2882.mp4', 'KICK_R_3294.mp4', 'KICK_R_1289.mp4', 'KICK_R_3111.mp4', 'KICK_R_3008.mp4', 'KICK_R_1587.mp4', 'KICK_R_1617.mp4', 'KICK_R_1496.mp4', 'KICK_R_4254.mp4', 'KICK_R_2870.mp4', 'KICK_R_2858.mp4', 'KICK_R_4073.mp4', 'KICK_R_4553.mp4', 'KICK_R_4079.mp4', 'KICK_R_3721.mp4'}
# {'KICK_R_4075.mp4', 'KICK_R_3437.mp4', 'KICK_R_3941.mp4', 'KICK_R_2882.mp4', 'KICK_R_1812.mp4', 'KICK_R_3816.mp4', 'KICK_R_1617.mp4', 'KICK_R_1543.mp4', 'KICK_R_4567.mp4', 'KICK_R_58.mp4', 'KICK_R_4079.mp4', 'KICK_R_4332.mp4', 'KICK_R_3553.mp4', 'KICK_R_1314.mp4'}
# {'KICK_R_2931.mp4', 'KICK_R_152.mp4', 'KICK_R_1583.mp4', 'KICK_R_3083.mp4', 'KICK_R_2830.mp4', 'KICK_R_3294.mp4', 'KICK_R_460.mp4', 'KICK_R_4565.mp4', 'KICK_R_3326.mp4', 'KICK_R_586.mp4', 'KICK_R_3110.mp4', 'KICK_R_4228.mp4', 'KICK_R_664.mp4', 'KICK_R_4073.mp4'}
# {'KICK_R_3581.mp4', 'KICK_R_983.mp4', 'KICK_R_973.mp4', 'KICK_R_322.mp4', 'KICK_R_3410.mp4', 'KICK_R_4039.mp4', 'KICK_R_3431.mp4', 'KICK_R_3912.mp4', 'KICK_R_151.mp4', 'KICK_R_4387.mp4', 'KICK_R_4566.mp4', 'KICK_R_1068.mp4', 'KICK_R_3112.mp4', 'KICK_R_4368.mp4', 'KICK_R_3442.mp4', 'KICK_R_1318.mp4', 'KICK_R_954.mp4', 'KICK_R_995.mp4', 'KICK_R_332.mp4', 'KICK_R_4538.mp4', 'KICK_R_3439.mp4', 'KICK_R_3126.mp4', 'KICK_R_1572.mp4', 'KICK_R_225.mp4', 'KICK_R_3742.mp4', 'KICK_R_305.mp4', 'KICK_R_1588.mp4', 'KICK_R_8.mp4', 'KICK_R_3082.mp4', 'KICK_R_4568.mp4', 'KICK_R_2791.mp4', 'KICK_R_3111.mp4', 'KICK_R_2961.mp4', 'KICK_R_1355.mp4', 'KICK_R_1289.mp4', 'KICK_R_337.mp4', 'KICK_R_3008.mp4', 'KICK_R_1587.mp4', 'KICK_R_1496.mp4', 'KICK_R_4254.mp4', 'KICK_R_2870.mp4', 'KICK_R_2858.mp4', 'KICK_R_4553.mp4', 'KICK_R_3721.mp4'}
# {'KICK_L_1305.mp4', 'KICK_L_468.mp4', 'KICK_L_113.mp4'}
# set()
# set()
# {'KICK_L_1305.mp4', 'KICK_L_468.mp4', 'KICK_L_113.mp4'}
# {'NOTHING_2411.mp4', 'NOTHING_2620.mp4', 'NOTHING_3488.mp4', 'NOTHING_4536.mp4', 'NOTHING_3862.mp4', 'NOTHING_3860.mp4', 'NOTHING_3325.mp4', 'NOTHING_235.mp4', 'NOTHING_3583.mp4', 'NOTHING_4259.mp4', 'NOTHING_1135.mp4', 'NOTHING_26.mp4', 'NOTHING_3934.mp4', 'NOTHING_2914.mp4', 'NOTHING_2689.mp4', 'NOTHING_3898.mp4', 'NOTHING_2778.mp4', 'NOTHING_2395.mp4', 'NOTHING_1025.mp4', 'NOTHING_1352.mp4', 'NOTHING_3874.mp4', 'NOTHING_4099.mp4', 'NOTHING_1032.mp4', 'NOTHING_2397.mp4', 'NOTHING_3699.mp4', 'NOTHING_3875.mp4', 'NOTHING_3924.mp4', 'NOTHING_996.mp4', 'NOTHING_1905.mp4', 'NOTHING_3285.mp4', 'NOTHING_2752.mp4', 'NOTHING_3416.mp4', 'NOTHING_4521.mp4', 'NOTHING_3432.mp4', 'NOTHING_2762.mp4', 'NOTHING_4303.mp4', 'NOTHING_3136.mp4', 'NOTHING_4027.mp4', 'NOTHING_4281.mp4', 'NOTHING_2633.mp4', 'NOTHING_4495.mp4', 'NOTHING_3675.mp4', 'NOTHING_3560.mp4', 'NOTHING_2174.mp4', 'NOTHING_3893.mp4', 'NOTHING_3094.mp4', 'NOTHING_81.mp4', 'NOTHING_4419.mp4', 'NOTHING_4305.mp4', 'NOTHING_3140.mp4', 'NOTHING_3475.mp4', 'NOTHING_1237.mp4', 'NOTHING_1462.mp4', 'NOTHING_1765.mp4', 'NOTHING_2986.mp4', 'NOTHING_4410.mp4', 'NOTHING_3091.mp4', 'NOTHING_536.mp4', 'NOTHING_3888.mp4', 'NOTHING_2305.mp4', 'NOTHING_438.mp4', 'NOTHING_3323.mp4', 'NOTHING_384.mp4', 'NOTHING_2284.mp4', 'NOTHING_765.mp4', 'NOTHING_2141.mp4', 'NOTHING_429.mp4', 'NOTHING_3636.mp4', 'NOTHING_2114.mp4', 'NOTHING_3684.mp4', 'NOTHING_3630.mp4', 'NOTHING_1016.mp4', 'NOTHING_2371.mp4', 'NOTHING_1116.mp4', 'NOTHING_4029.mp4', 'NOTHING_2734.mp4', 'NOTHING_455.mp4', 'NOTHING_2679.mp4', 'NOTHING_566.mp4', 'NOTHING_731.mp4', 'NOTHING_4226.mp4', 'NOTHING_1330.mp4', 'NOTHING_736.mp4', 'NOTHING_4569.mp4', 'NOTHING_2467.mp4', 'NOTHING_832.mp4', 'NOTHING_3144.mp4', 'NOTHING_3420.mp4', 'NOTHING_1533.mp4', 'NOTHING_4115.mp4', 'NOTHING_3624.mp4', 'NOTHING_2712.mp4', 'NOTHING_2110.mp4', 'NOTHING_2979.mp4', 'NOTHING_2944.mp4', 'NOTHING_3321.mp4', 'NOTHING_3525.mp4', 'NOTHING_2297.mp4', 'NOTHING_970.mp4', 'NOTHING_2456.mp4', 'NOTHING_4432.mp4', 'NOTHING_1610.mp4', 'NOTHING_1196.mp4', 'NOTHING_1261.mp4', 'NOTHING_1472.mp4', 'NOTHING_2578.mp4', 'NOTHING_3786.mp4', 'NOTHING_3330.mp4', 'NOTHING_4551.mp4', 'NOTHING_2293.mp4', 'NOTHING_3364.mp4', 'NOTHING_3516.mp4', 'NOTHING_1241.mp4', 'NOTHING_505.mp4', 'NOTHING_2907.mp4', 'NOTHING_1378.mp4', 'NOTHING_4509.mp4', 'NOTHING_1517.mp4', 'NOTHING_2555.mp4', 'NOTHING_2737.mp4', 'NOTHING_59.mp4', 'NOTHING_3884.mp4', 'NOTHING_3945.mp4', 'NOTHING_248.mp4', 'NOTHING_2438.mp4', 'NOTHING_4542.mp4', 'NOTHING_3299.mp4', 'NOTHING_3739.mp4', 'NOTHING_2928.mp4', 'NOTHING_3484.mp4', 'NOTHING_1279.mp4', 'NOTHING_2942.mp4', 'NOTHING_2972.mp4', 'NOTHING_2248.mp4', 'NOTHING_2787.mp4', 'NOTHING_569.mp4', 'NOTHING_2976.mp4', 'NOTHING_4107.mp4', 'NOTHING_68.mp4', 'NOTHING_4289.mp4', 'NOTHING_1768.mp4', 'NOTHING_1938.mp4', 'NOTHING_3197.mp4', 'NOTHING_2913.mp4', 'NOTHING_645.mp4', 'NOTHING_3932.mp4', 'NOTHING_2231.mp4', 'NOTHING_4522.mp4', 'NOTHING_688.mp4', 'NOTHING_676.mp4', 'NOTHING_593.mp4', 'NOTHING_4060.mp4', 'NOTHING_1143.mp4', 'NOTHING_4296.mp4', 'NOTHING_2215.mp4', 'NOTHING_741.mp4', 'NOTHING_1910.mp4', 'NOTHING_4361.mp4', 'NOTHING_1315.mp4', 'NOTHING_3882.mp4', 'NOTHING_2478.mp4', 'NOTHING_3794.mp4', 'NOTHING_2289.mp4', 'NOTHING_1614.mp4', 'NOTHING_4282.mp4', 'NOTHING_2535.mp4', 'NOTHING_226.mp4', 'NOTHING_343.mp4', 'NOTHING_668.mp4', 'NOTHING_4198.mp4', 'NOTHING_4457.mp4', 'NOTHING_3820.mp4', 'NOTHING_3824.mp4', 'NOTHING_2936.mp4', 'NOTHING_1593.mp4', 'NOTHING_3468.mp4', 'NOTHING_924.mp4', 'NOTHING_1119.mp4', 'NOTHING_437.mp4', 'NOTHING_2625.mp4', 'NOTHING_1021.mp4', 'NOTHING_1881.mp4', 'NOTHING_4530.mp4', 'NOTHING_1408.mp4', 'NOTHING_2374.mp4', 'NOTHING_3489.mp4', 'NOTHING_3813.mp4', 'NOTHING_1946.mp4', 'NOTHING_1107.mp4', 'NOTHING_843.mp4', 'NOTHING_2641.mp4', 'NOTHING_1254.mp4', 'NOTHING_969.mp4', 'NOTHING_1280.mp4', 'NOTHING_1681.mp4', 'NOTHING_2843.mp4', 'NOTHING_3188.mp4', 'NOTHING_3749.mp4', 'NOTHING_1611.mp4', 'NOTHING_233.mp4', 'NOTHING_2614.mp4', 'NOTHING_2522.mp ...
# {'NOTHING_4270.mp4', 'NOTHING_3594.mp4', 'NOTHING_309.mp4', 'NOTHING_1283.mp4', 'NOTHING_2620.mp4', 'NOTHING_3914.mp4', 'NOTHING_4013.mp4', 'NOTHING_2255.mp4', 'NOTHING_4335.mp4', 'NOTHING_1240.mp4', 'NOTHING_4112.mp4', 'NOTHING_3740.mp4', 'NOTHING_4002.mp4', 'NOTHING_4015.mp4', 'NOTHING_235.mp4', 'NOTHING_2654.mp4', 'NOTHING_3934.mp4', 'NOTHING_2914.mp4', 'NOTHING_1139.mp4', 'NOTHING_3898.mp4', 'NOTHING_2395.mp4', 'NOTHING_1773.mp4', 'NOTHING_1191.mp4', 'NOTHING_1352.mp4', 'NOTHING_3905.mp4', 'NOTHING_1032.mp4', 'NOTHING_2397.mp4', 'NOTHING_2113.mp4', 'NOTHING_2330.mp4', 'NOTHING_2503.mp4', 'NOTHING_1007.mp4', 'NOTHING_1770.mp4', 'NOTHING_3285.mp4', 'NOTHING_1067.mp4', 'NOTHING_2743.mp4', 'NOTHING_1395.mp4', 'NOTHING_1679.mp4', 'NOTHING_3568.mp4', 'NOTHING_1501.mp4', 'NOTHING_3000.mp4', 'NOTHING_2491.mp4', 'NOTHING_3560.mp4', 'NOTHING_3893.mp4', 'NOTHING_4292.mp4', 'NOTHING_3475.mp4', 'NOTHING_1237.mp4', 'NOTHING_1765.mp4', 'NOTHING_738.mp4', 'NOTHING_1503.mp4', 'NOTHING_3216.mp4', 'NOTHING_3797.mp4', 'NOTHING_1049.mp4', 'NOTHING_1474.mp4', 'NOTHING_3323.mp4', 'NOTHING_765.mp4', 'NOTHING_3793.mp4', 'NOTHING_3328.mp4', 'NOTHING_3697.mp4', 'NOTHING_455.mp4', 'NOTHING_107.mp4', 'NOTHING_87.mp4', 'NOTHING_1690.mp4', 'NOTHING_2679.mp4', 'NOTHING_566.mp4', 'NOTHING_433.mp4', 'NOTHING_4007.mp4', 'NOTHING_1719.mp4', 'NOTHING_832.mp4', 'NOTHING_1186.mp4', 'NOTHING_951.mp4', 'NOTHING_2484.mp4', 'NOTHING_2710.mp4', 'NOTHING_2147.mp4', 'NOTHING_2459.mp4', 'NOTHING_3783.mp4', 'NOTHING_299.mp4', 'NOTHING_4207.mp4', 'NOTHING_1245.mp4', 'NOTHING_2546.mp4', 'NOTHING_3392.mp4', 'NOTHING_3428.mp4', 'NOTHING_3786.mp4', 'NOTHING_4389.mp4', 'NOTHING_2686.mp4', 'NOTHING_3516.mp4', 'NOTHING_505.mp4', 'NOTHING_1042.mp4', 'NOTHING_932.mp4', 'NOTHING_3892.mp4', 'NOTHING_3945.mp4', 'NOTHING_71.mp4', 'NOTHING_3894.mp4', 'NOTHING_846.mp4', 'NOTHING_2530.mp4', 'NOTHING_2594.mp4', 'NOTHING_1152.mp4', 'NOTHING_921.mp4', 'NOTHING_1052.mp4', 'NOTHING_3538.mp4', 'NOTHING_1206.mp4', 'NOTHING_4107.mp4', 'NOTHING_2556.mp4', 'NOTHING_2724.mp4', 'NOTHING_2403.mp4', 'NOTHING_1952.mp4', 'NOTHING_3761.mp4', 'NOTHING_2913.mp4', 'NOTHING_2405.mp4', 'NOTHING_1605.mp4', 'NOTHING_3734.mp4', 'NOTHING_2662.mp4', 'NOTHING_2725.mp4', 'NOTHING_4522.mp4', 'NOTHING_2348.mp4', 'NOTHING_3098.mp4', 'NOTHING_139.mp4', 'NOTHING_676.mp4', 'NOTHING_1829.mp4', 'NOTHING_3396.mp4', 'NOTHING_3707.mp4', 'NOTHING_3147.mp4', 'NOTHING_2215.mp4', 'NOTHING_1337.mp4', 'NOTHING_2353.mp4', 'NOTHING_2132.mp4', 'NOTHING_3794.mp4', 'NOTHING_1177.mp4', 'NOTHING_1614.mp4', 'NOTHING_3108.mp4', 'NOTHING_3280.mp4', 'NOTHING_3596.mp4', 'NOTHING_2813.mp4', 'NOTHING_4585.mp4', 'NOTHING_4584.mp4', 'NOTHING_1593.mp4', 'NOTHING_3824.mp4', 'NOTHING_2334.mp4', 'NOTHING_164.mp4', 'NOTHING_2252.mp4', 'NOTHING_1805.mp4', 'NOTHING_2433.mp4', 'NOTHING_4429.mp4', 'NOTHING_2549.mp4', 'NOTHING_1942.mp4', 'NOTHING_3071.mp4', 'NOTHING_3944.mp4', 'NOTHING_2656.mp4', 'NOTHING_104.mp4', 'NOTHING_1427.mp4', 'NOTHING_3681.mp4', 'NOTHING_4530.mp4', 'NOTHING_1296.mp4', 'NOTHING_2983.mp4', 'NOTHING_1254.mp4', 'NOTHING_2619.mp4', 'NOTHING_4362.mp4', 'NOTHING_984.mp4', 'NOTHING_3749.mp4', 'NOTHING_1600.mp4', 'NOTHING_1246.mp4', 'NOTHING_665.mp4', 'NOTHING_1022.mp4', 'NOTHING_2347.mp4', 'NOTHING_1606.mp4', 'NOTHING_1730.mp4', 'NOTHING_2527.mp4', 'NOTHING_1239.mp4', 'NOTHING_4369.mp4', 'NOTHING_3784.mp4', 'NOTHING_1165.mp4', 'NOTHING_2344.mp4', 'NOTHING_2823.mp4', 'NOTHING_2485.mp4', 'NOTHING_2611.mp4', 'NOTHING_4540.mp4', 'NOTHING_2507.mp4', 'NOTHING_2389.mp4', 'NOTHING_187.mp4', 'NOTHING_936.mp4', 'NOTHING_4390.mp4', 'NOTHING_2494.mp4', 'NOTHING_3753.mp4', 'NOTHING_94.mp4', 'NOTHING_1066.mp4', 'NOTHING_4209.mp4', 'NOTHING_1010.mp4', 'NOTHING_1672.mp4', 'NOTHING_2519.mp4', 'NOTHING_2250.mp4', 'NOTHING_1753.mp4', 'NOTHING_3796.mp4', 'NOTHING_222.mp4', 'NOTHING_3283.mp4', 'NOTHING_1864.mp4', 'NOTHING_1814.mp4', 'NOTHING_112.mp4', 'NOTHING_3858.mp4', 'NOTHING_729.mp4', 'NOTHING_2541.mp4', 'NOTHING_1390.mp4', 'NOTHING_2412.mp4', 'NOTHING_76 ...
# {'NOTHING_2411.mp4', 'NOTHING_2332.mp4', 'NOTHING_4494.mp4', 'NOTHING_4536.mp4', 'NOTHING_4125.mp4', 'NOTHING_2987.mp4', 'NOTHING_3322.mp4', 'NOTHING_425.mp4', 'NOTHING_3687.mp4', 'NOTHING_297.mp4', 'NOTHING_3583.mp4', 'NOTHING_1706.mp4', 'NOTHING_675.mp4', 'NOTHING_1724.mp4', 'NOTHING_20.mp4', 'NOTHING_2778.mp4', 'NOTHING_3365.mp4', 'NOTHING_1123.mp4', 'NOTHING_2934.mp4', 'NOTHING_2424.mp4', 'NOTHING_2179.mp4', 'NOTHING_2648.mp4', 'NOTHING_4103.mp4', 'NOTHING_4018.mp4', 'NOTHING_3699.mp4', 'NOTHING_2460.mp4', 'NOTHING_2370.mp4', 'NOTHING_142.mp4', 'NOTHING_1339.mp4', 'NOTHING_157.mp4', 'NOTHING_996.mp4', 'NOTHING_2839.mp4', 'NOTHING_2626.mp4', 'NOTHING_3432.mp4', 'NOTHING_72.mp4', 'NOTHING_4051.mp4', 'NOTHING_829.mp4', 'NOTHING_417.mp4', 'NOTHING_3048.mp4', 'NOTHING_4407.mp4', 'NOTHING_4255.mp4', 'NOTHING_1955.mp4', 'NOTHING_2910.mp4', 'NOTHING_2473.mp4', 'NOTHING_4495.mp4', 'NOTHING_3706.mp4', 'NOTHING_4000.mp4', 'NOTHING_3094.mp4', 'NOTHING_119.mp4', 'NOTHING_81.mp4', 'NOTHING_3951.mp4', 'NOTHING_961.mp4', 'NOTHING_3140.mp4', 'NOTHING_1867.mp4', 'NOTHING_1160.mp4', 'NOTHING_692.mp4', 'NOTHING_2745.mp4', 'NOTHING_4410.mp4', 'NOTHING_1181.mp4', 'NOTHING_4286.mp4', 'NOTHING_1392.mp4', 'NOTHING_1023.mp4', 'NOTHING_3617.mp4', 'NOTHING_1513.mp4', 'NOTHING_3001.mp4', 'NOTHING_2978.mp4', 'NOTHING_2831.mp4', 'NOTHING_270.mp4', 'NOTHING_457.mp4', 'NOTHING_3552.mp4', 'NOTHING_4171.mp4', 'NOTHING_1053.mp4', 'NOTHING_1566.mp4', 'NOTHING_2141.mp4', 'NOTHING_3684.mp4', 'NOTHING_966.mp4', 'NOTHING_891.mp4', 'NOTHING_2371.mp4', 'NOTHING_1116.mp4', 'NOTHING_3010.mp4', 'NOTHING_2734.mp4', 'NOTHING_2664.mp4', 'NOTHING_896.mp4', 'NOTHING_2102.mp4', 'NOTHING_949.mp4', 'NOTHING_4569.mp4', 'NOTHING_1633.mp4', 'NOTHING_528.mp4', 'NOTHING_1259.mp4', 'NOTHING_3420.mp4', 'NOTHING_835.mp4', 'NOTHING_3624.mp4', 'NOTHING_2712.mp4', 'NOTHING_3780.mp4', 'NOTHING_2944.mp4', 'NOTHING_3788.mp4', 'NOTHING_2609.mp4', 'NOTHING_970.mp4', 'NOTHING_1281.mp4', 'NOTHING_1472.mp4', 'NOTHING_3178.mp4', 'NOTHING_4587.mp4', 'NOTHING_2293.mp4', 'NOTHING_519.mp4', 'NOTHING_1162.mp4', 'NOTHING_1885.mp4', 'NOTHING_1907.mp4', 'NOTHING_1517.mp4', 'NOTHING_1144.mp4', 'NOTHING_3531.mp4', 'NOTHING_1676.mp4', 'NOTHING_4511.mp4', 'NOTHING_4542.mp4', 'NOTHING_3299.mp4', 'NOTHING_162.mp4', 'NOTHING_2268.mp4', 'NOTHING_342.mp4', 'NOTHING_4066.mp4', 'NOTHING_1921.mp4', 'NOTHING_3739.mp4', 'NOTHING_114.mp4', 'NOTHING_4346.mp4', 'NOTHING_1155.mp4', 'NOTHING_865.mp4', 'NOTHING_4416.mp4', 'NOTHING_1894.mp4', 'NOTHING_3765.mp4', 'NOTHING_4289.mp4', 'NOTHING_186.mp4', 'NOTHING_219.mp4', 'NOTHING_3197.mp4', 'NOTHING_4496.mp4', 'NOTHING_645.mp4', 'NOTHING_2231.mp4', 'NOTHING_4003.mp4', 'NOTHING_3727.mp4', 'NOTHING_1732.mp4', 'NOTHING_4031.mp4', 'NOTHING_2836.mp4', 'NOTHING_1050.mp4', 'NOTHING_4529.mp4', 'NOTHING_4361.mp4', 'NOTHING_334.mp4', 'NOTHING_3882.mp4', 'NOTHING_4212.mp4', 'NOTHING_189.mp4', 'NOTHING_343.mp4', 'NOTHING_2331.mp4', 'NOTHING_3587.mp4', 'NOTHING_4457.mp4', 'NOTHING_2936.mp4', 'NOTHING_4100.mp4', 'NOTHING_65.mp4', 'NOTHING_3933.mp4', 'NOTHING_3265.mp4', 'NOTHING_411.mp4', 'NOTHING_3341.mp4', 'NOTHING_1540.mp4', 'NOTHING_242.mp4', 'NOTHING_2625.mp4', 'NOTHING_4095.mp4', 'NOTHING_1771.mp4', 'NOTHING_1011.mp4', 'NOTHING_4501.mp4', 'NOTHING_4152.mp4', 'NOTHING_2152.mp4', 'NOTHING_2776.mp4', 'NOTHING_4337.mp4', 'NOTHING_2226.mp4', 'NOTHING_969.mp4', 'NOTHING_2167.mp4', 'NOTHING_4092.mp4', 'NOTHING_3738.mp4', 'NOTHING_3524.mp4', 'NOTHING_496.mp4', 'NOTHING_2614.mp4', 'NOTHING_2784.mp4', 'NOTHING_2522.mp4', 'NOTHING_4582.mp4', 'NOTHING_523.mp4', 'NOTHING_1017.mp4', 'NOTHING_4580.mp4', 'NOTHING_3142.mp4', 'NOTHING_2151.mp4', 'NOTHING_3698.mp4', 'NOTHING_370.mp4', 'NOTHING_3261.mp4', 'NOTHING_2759.mp4', 'NOTHING_1750.mp4', 'NOTHING_1815.mp4', 'NOTHING_1403.mp4', 'NOTHING_1443.mp4', 'NOTHING_3469.mp4', 'NOTHING_3105.mp4', 'NOTHING_3485.mp4', 'NOTHING_915.mp4', 'NOTHING_2375.mp4', 'NOTHING_3548.mp4', 'NOTHING_3209.mp4', 'NOTHING_2376.mp4', 'NOTHING_3081.mp4', 'NOTHING_3792.mp4', 'NOTH ...
# {'NOTHING_3488.mp4', 'NOTHING_3862.mp4', 'NOTHING_3860.mp4', 'NOTHING_3325.mp4', 'NOTHING_4259.mp4', 'NOTHING_1135.mp4', 'NOTHING_26.mp4', 'NOTHING_2689.mp4', 'NOTHING_1025.mp4', 'NOTHING_3874.mp4', 'NOTHING_4099.mp4', 'NOTHING_3875.mp4', 'NOTHING_3924.mp4', 'NOTHING_1905.mp4', 'NOTHING_2752.mp4', 'NOTHING_3416.mp4', 'NOTHING_4521.mp4', 'NOTHING_2762.mp4', 'NOTHING_4303.mp4', 'NOTHING_3136.mp4', 'NOTHING_4027.mp4', 'NOTHING_4281.mp4', 'NOTHING_2633.mp4', 'NOTHING_3675.mp4', 'NOTHING_2174.mp4', 'NOTHING_4419.mp4', 'NOTHING_4305.mp4', 'NOTHING_1462.mp4', 'NOTHING_2986.mp4', 'NOTHING_3091.mp4', 'NOTHING_536.mp4', 'NOTHING_3888.mp4', 'NOTHING_2305.mp4', 'NOTHING_438.mp4', 'NOTHING_384.mp4', 'NOTHING_2284.mp4', 'NOTHING_429.mp4', 'NOTHING_3636.mp4', 'NOTHING_2114.mp4', 'NOTHING_3630.mp4', 'NOTHING_1016.mp4', 'NOTHING_4029.mp4', 'NOTHING_736.mp4', 'NOTHING_731.mp4', 'NOTHING_1330.mp4', 'NOTHING_4226.mp4', 'NOTHING_2467.mp4', 'NOTHING_3144.mp4', 'NOTHING_1533.mp4', 'NOTHING_4115.mp4', 'NOTHING_2110.mp4', 'NOTHING_2979.mp4', 'NOTHING_3525.mp4', 'NOTHING_3321.mp4', 'NOTHING_2297.mp4', 'NOTHING_2456.mp4', 'NOTHING_1610.mp4', 'NOTHING_4432.mp4', 'NOTHING_1196.mp4', 'NOTHING_1261.mp4', 'NOTHING_2578.mp4', 'NOTHING_3330.mp4', 'NOTHING_4551.mp4', 'NOTHING_3364.mp4', 'NOTHING_1241.mp4', 'NOTHING_2907.mp4', 'NOTHING_1378.mp4', 'NOTHING_4509.mp4', 'NOTHING_2555.mp4', 'NOTHING_2737.mp4', 'NOTHING_59.mp4', 'NOTHING_3884.mp4', 'NOTHING_248.mp4', 'NOTHING_2438.mp4', 'NOTHING_2928.mp4', 'NOTHING_1279.mp4', 'NOTHING_3484.mp4', 'NOTHING_2942.mp4', 'NOTHING_2972.mp4', 'NOTHING_2248.mp4', 'NOTHING_2787.mp4', 'NOTHING_569.mp4', 'NOTHING_2976.mp4', 'NOTHING_68.mp4', 'NOTHING_1938.mp4', 'NOTHING_1768.mp4', 'NOTHING_3932.mp4', 'NOTHING_688.mp4', 'NOTHING_593.mp4', 'NOTHING_4060.mp4', 'NOTHING_1143.mp4', 'NOTHING_4296.mp4', 'NOTHING_741.mp4', 'NOTHING_1910.mp4', 'NOTHING_1315.mp4', 'NOTHING_2478.mp4', 'NOTHING_2289.mp4', 'NOTHING_4282.mp4', 'NOTHING_2535.mp4', 'NOTHING_226.mp4', 'NOTHING_668.mp4', 'NOTHING_4198.mp4', 'NOTHING_3820.mp4', 'NOTHING_3468.mp4', 'NOTHING_924.mp4', 'NOTHING_1119.mp4', 'NOTHING_437.mp4', 'NOTHING_1021.mp4', 'NOTHING_1881.mp4', 'NOTHING_1408.mp4', 'NOTHING_2374.mp4', 'NOTHING_3489.mp4', 'NOTHING_3813.mp4', 'NOTHING_1946.mp4', 'NOTHING_1107.mp4', 'NOTHING_843.mp4', 'NOTHING_2641.mp4', 'NOTHING_1280.mp4', 'NOTHING_1681.mp4', 'NOTHING_2843.mp4', 'NOTHING_3188.mp4', 'NOTHING_1611.mp4', 'NOTHING_233.mp4', 'NOTHING_3709.mp4', 'NOTHING_3374.mp4', 'NOTHING_4517.mp4', 'NOTHING_2392.mp4', 'NOTHING_4518.mp4', 'NOTHING_1251.mp4', 'NOTHING_4176.mp4', 'NOTHING_4301.mp4', 'NOTHING_704.mp4', 'NOTHING_2607.mp4', 'NOTHING_3650.mp4', 'NOTHING_4285.mp4', 'NOTHING_3686.mp4', 'NOTHING_1428.mp4', 'NOTHING_4022.mp4', 'NOTHING_871.mp4', 'NOTHING_3300.mp4', 'NOTHING_1367.mp4', 'NOTHING_1133.mp4', 'NOTHING_2241.mp4', 'NOTHING_349.mp4', 'NOTHING_1525.mp4', 'NOTHING_4485.mp4', 'NOTHING_1624.mp4', 'NOTHING_374.mp4', 'NOTHING_702.mp4', 'NOTHING_2965.mp4', 'NOTHING_188.mp4', 'NOTHING_4308.mp4', 'NOTHING_1523.mp4', 'NOTHING_2470.mp4', 'NOTHING_2765.mp4', 'NOTHING_1564.mp4', 'NOTHING_201.mp4', 'NOTHING_3361.mp4', 'NOTHING_4194.mp4', 'NOTHING_2288.mp4', 'NOTHING_1741.mp4', 'NOTHING_787.mp4', 'NOTHING_3689.mp4', 'NOTHING_2308.mp4', 'NOTHING_1442.mp4', 'NOTHING_3997.mp4', 'NOTHING_2253.mp4', 'NOTHING_28.mp4', 'NOTHING_777.mp4', 'NOTHING_2922.mp4', 'NOTHING_2217.mp4', 'NOTHING_1430.mp4', 'NOTHING_2537.mp4', 'NOTHING_2314.mp4', 'NOTHING_2341.mp4', 'NOTHING_603.mp4', 'NOTHING_3804.mp4', 'NOTHING_1174.mp4', 'NOTHING_2287.mp4', 'NOTHING_2169.mp4', 'NOTHING_85.mp4', 'NOTHING_2553.mp4', 'NOTHING_1563.mp4', 'NOTHING_2670.mp4', 'NOTHING_1527.mp4', 'NOTHING_1285.mp4', 'NOTHING_3418.mp4', 'NOTHING_3683.mp4', 'NOTHING_899.mp4', 'NOTHING_1874.mp4', 'NOTHING_3904.mp4', 'NOTHING_937.mp4', 'NOTHING_1054.mp4', 'NOTHING_2845.mp4', 'NOTHING_500.mp4', 'NOTHING_1870.mp4', 'NOTHING_202.mp4', 'NOTHING_642.mp4', 'NOTHING_2510.mp4', 'NOTHING_3743.mp4', 'NOTHING_1301.mp4', 'NOTHING_1457.mp4', ' ...
